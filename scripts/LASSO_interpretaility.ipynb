# %% [markdown]
# ## Naive SLERP

# %%
# !slerp_merge \
yedi-hu/slerp_llama_2_child-2-6-float16 \
yedi-hu/Llama-2-7b-truthfulqa-float16 \
./slerp_llama_2_child-3-2-float16
# Out:
# config.json: 100% 698/698 [00:00<00:00, 5.90MB/s]
# model.safetensors.index.json: 24.0kB [00:00, 83.9MB/s]
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
#
# model-00003-of-00003.safetensors:   0% 0.00/3.59G [00:00<?, ?B/s]
#
#
# model-00002-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.94G [00:00<00:49, 99.4MB/s]
#
# model-00003-of-00003.safetensors:   0% 10.5M/3.59G [00:00<00:40, 88.5MB/s]
#
#
# model-00002-of-00003.safetensors:   0% 10.5M/4.95G [00:00<01:07, 72.9MB/s]
# model-00001-of-00003.safetensors:   1% 41.9M/4.94G [00:00<00:27, 180MB/s]
#
# model-00003-of-00003.safetensors:   1% 41.9M/3.59G [00:00<00:20, 174MB/s]
#
#
# model-00002-of-00003.safetensors:   1% 31.5M/4.95G [00:00<00:37, 131MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.94G [00:00<00:22, 216MB/s]
#
# model-00003-of-00003.safetensors:   2% 73.4M/3.59G [00:00<00:16, 210MB/s]
# model-00001-of-00003.safetensors:   2% 105M/4.94G [00:00<00:20, 237MB/s]
#
# model-00003-of-00003.safetensors:   3% 105M/3.59G [00:00<00:14, 235MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.94G [00:00<00:18, 254MB/s]
#
# model-00003-of-00003.safetensors:   4% 136M/3.59G [00:00<00:13, 252MB/s]
#
#
# model-00002-of-00003.safetensors:   1% 52.4M/4.95G [00:00<00:50, 96.1MB/s]
# model-00001-of-00003.safetensors:   3% 168M/4.94G [00:00<00:18, 263MB/s]
#
# model-00003-of-00003.safetensors:   5% 168M/3.59G [00:00<00:13, 257MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.94G [00:00<00:17, 275MB/s]
#
# model-00003-of-00003.safetensors:   6% 199M/3.59G [00:00<00:12, 266MB/s]
#
#
# model-00002-of-00003.safetensors:   1% 73.4M/4.95G [00:00<00:50, 96.7MB/s]
# model-00001-of-00003.safetensors:   5% 231M/4.94G [00:00<00:16, 281MB/s]
#
# model-00003-of-00003.safetensors:   6% 231M/3.59G [00:00<00:12, 271MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.94G [00:01<00:16, 283MB/s]
#
#
# model-00002-of-00003.safetensors:   2% 83.9M/4.95G [00:00<00:59, 81.5MB/s]
#
# model-00003-of-00003.safetensors:   7% 262M/3.59G [00:01<00:12, 269MB/s]
# model-00001-of-00003.safetensors:   6% 294M/4.94G [00:01<00:16, 283MB/s]
#
# model-00003-of-00003.safetensors:   8% 294M/3.59G [00:01<00:11, 276MB/s]
#
#
# model-00002-of-00003.safetensors:   2% 105M/4.95G [00:01<00:51, 93.4MB/s]
# model-00001-of-00003.safetensors:   7% 325M/4.94G [00:01<00:16, 286MB/s]
#
# model-00003-of-00003.safetensors:   9% 325M/3.59G [00:01<00:12, 269MB/s]
# model-00001-of-00003.safetensors:   7% 357M/4.94G [00:01<00:16, 272MB/s]
#
#
# model-00002-of-00003.safetensors:   2% 115M/4.95G [00:01<00:58, 82.0MB/s]
#
# model-00003-of-00003.safetensors:  10% 357M/3.59G [00:01<00:12, 267MB/s]
#
# model-00003-of-00003.safetensors:  11% 388M/3.59G [00:01<00:11, 270MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.94G [00:01<00:19, 234MB/s]
#
#
# model-00002-of-00003.safetensors:   3% 136M/4.95G [00:01<00:52, 92.2MB/s]
#
# model-00003-of-00003.safetensors:  12% 419M/3.59G [00:01<00:11, 268MB/s]
#
#
# model-00002-of-00003.safetensors:   3% 157M/4.95G [00:01<00:44, 109MB/s]
# model-00001-of-00003.safetensors:   8% 419M/4.94G [00:01<00:21, 208MB/s]
#
# model-00003-of-00003.safetensors:  13% 451M/3.59G [00:01<00:11, 269MB/s]
#
# model-00003-of-00003.safetensors:  13% 482M/3.59G [00:01<00:12, 253MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.94G [00
/s]
#
#
# model-00002-of-00003.safetensors:  96% 4.73G/4.95G [07:34<04:48, 758kB/s]
#
#
# model-00002-of-00003.safetensors:  96% 4.76G/4.95G [07:34<02:30, 1.24MB/s]
#
# model-00001-of-00003.safetensors:  91% 4.49G/4.94G [07:34<14:05, 533kB/s]
#
#
# model-00002-of-00003.safetensors:  97% 4.79G/4.95G [07:34<01:20, 1.93MB/s]
#
# model-00001-of-00003.safetensors:  92% 4.52G/4.94G [07:34<08:01, 872kB/s]
#
#
# model-00002-of-00003.safetensors:  97% 4.82G/4.95G [07:34<00:42, 2.90MB/s]
#
# model-00001-of-00003.safetensors:  92% 4.55G/4.94G [07:34<04:46, 1.35MB/s]
#
#
# model-00002-of-00003.safetensors:  98% 4.85G/4.95G [07:34<00:21, 4.28MB/s]
#
# model-00001-of-00003.safetensors:  93% 4.58G/4.94G [07:34<02:55, 2.04MB/s]
#
#
# model-00002-of-00003.safetensors:  99% 4.89G/4.95G [07:34<00:09, 6.23MB/s]
#
# model-00001-of-00003.safetensors:  93% 4.61G/4.94G [07:34<01:48, 3.01MB/s]
#
#
# model-00002-of-00003.safetensors:  99% 4.92G/4.95G [07:34<00:03, 8.96MB/s]
#
# model-00001-of-00003.safetensors:  94% 4.65G/4.94G [07:35<01:07, 4.38MB/s]
#
#
# model-00002-of-00003.safetensors: 100% 4.95G/4.95G [07:35<00:00, 10.9MB/s]
#
#
# model-00001-of-00003.safetensors:  95% 4.68G/4.94G [07:35<00:41, 6.31MB/s]
#
# model-00001-of-00003.safetensors:  95% 4.71G/4.94G [07:35<00:25, 8.98MB/s]
#
# model-00001-of-00003.safetensors:  96% 4.73G/4.94G [07:35<00:18, 11.4MB/s]
#
# model-00001-of-00003.safetensors:  96% 4.75G/4.94G [07:35<00:12, 14.8MB/s]
#
# model-00001-of-00003.safetensors:  97% 4.77G/4.94G [07:35<00:08, 19.4MB/s]
#
# model-00001-of-00003.safetensors:  97% 4.79G/4.94G [07:35<00:05, 25.4MB/s]
#
# model-00001-of-00003.safetensors:  97% 4.81G/4.94G [07:36<00:03, 33.2MB/s]
#
# model-00001-of-00003.safetensors:  98% 4.83G/4.94G [07:36<00:02, 42.8MB/s]
#
# model-00001-of-00003.safetensors:  98% 4.85G/4.94G [07:36<00:01, 54.4MB/s]
#
# model-00001-of-00003.safetensors:  99% 4.88G/4.94G [07:36<00:00, 67.4MB/s]
#
# model-00001-of-00003.safetensors:  99% 4.90G/4.94G [07:36<00:00, 81.4MB/s]
#
# model-00001-of-00003.safetensors: 100% 4.92G/4.94G [07:36<00:00, 95.4MB/s]
#
# model-00001-of-00003.safetensors: 100% 4.94G/4.94G [07:36<00:00, 10.8MB/s]
# Fetching 3 files: 100% 3/3 [07:37<00:00, 152.39s/it]
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.00s/it]
# generation_config.json: 100% 183/183 [00:00<00:00, 1.92MB/s]
# Saving merged model to ./slerp_llama_2_child-3-2-float16
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.16s/it]
# tokenizer_config.json: 100% 980/980 [00:00<00:00, 10.8MB/s]
# tokenizer.json: 3.62MB [00:00, 29.4MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 3.82MB/s]

# %%
from huggingface_hub import HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'slerp_llama_2_child-3-2-float16' # @param {"type":"string"}
repo_name=f'yedi-hu/{model_name}'
model_path=f'./{model_name}'
token='yours'

api = HfApi()

try:
    api.create_repo(
        repo_id=repo_name,
        private=False,
        exist_ok=True
      )
except Exception as e:
      raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")

  # Load the model and tokenizer
# model = AutoModelForCausalLM.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

api.upload_folder(
    folder_path=model_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)


print(f"✅ Model successfully uploaded to: https://huggingface.co/{repo_name}")
# Out:
# Uploading model to yedi-hu/slerp_llama_2_child-3-2-float16...
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# ✅ Model successfully uploaded to: https://huggingface.co/yedi-hu/slerp_llama_2_child-3-2-float16

# %% [markdown]
# ## Llama-2

# %%
import pandas as pd

df = pd.read_csv('./llama2_4tasks_deltas_gen_1.csv')
print(df.keys())

for index, row in df.iterrows():
  parent = row['parent']
  child = row['child']
  print(f"Parent: {parent}, Child: {child}")
# Out:
# Index(['delta_norm', 'parent', 'child', 'change_winogrande', 'change_gsm8k',
#        'change_mmlu', 'change_truthfulqa', 'change_average'],
#       dtype='object')
# Parent: yedi-hu/Llama-2-7b-gsm8k-float16, Child: yedi-hu/slerp_llama_2_child-1-6-float16
# Parent: yedi-hu/Llama-2-7b-mmlu-float16, Child: yedi-hu/slerp_llama_2_child-1-3-float16
# Parent: yedi-hu/Llama-2-7b-winogrande-float16, Child: yedi-hu/slerp_llama_2_child-1-5-float16
# Parent: yedi-hu/Llama-2-7b-gsm8k-float16, Child: yedi-hu/slerp_llama_2_child-1-4-float16
# Parent: yedi-hu/Llama-2-7b-gsm8k-float16, Child: yedi-hu/slerp_llama_2_child-1-1-float16
# Parent: yedi-hu/Llama-2-7b-mmlu-float16, Child: yedi-hu/slerp_llama_2_child-1-2-float16
# Parent: yedi-hu/Llama-2-7b-mmlu-float16, Child: yedi-hu/slerp_llama_2_child-1-4-float16
# Parent: yedi-hu/Llama-2-7b-winogrande-float16, Child: yedi-hu/slerp_llama_2_child-1-2-float16
# Parent: yedi-hu/Llama-2-7b-winogrande-float16, Child: yedi-hu/slerp_llama_2_child-1-1-float16
# Parent: yedi-hu/Llama-2-7b-truthfulqa-float16, Child: yedi-hu/slerp_llama_2_child-1-3-float16
# Parent: yedi-hu/Llama-2-7b-truthfulqa-float16, Child: yedi-hu/slerp_llama_2_child-1-5-float16
# Parent: yedi-hu/Llama-2-7b-truthfulqa-float16, Child: yedi-hu/slerp_llama_2_child-1-6-float16

# %%
import os

if not os.path.exists('./llama2_4tasks_deltas_gen_1_chunks_10/'):
    os.makedirs('./llama2_4tasks_deltas_gen_1_chunks_10/')
i=0
for index, row in df.iterrows():
  # if i >= 10:
  #   break
  if i < 10:
    i+=1
    continue
  parent = row['parent']
  child = row['child']
  delta_addr = './llama2_4tasks_deltas_gen_1_chunks_10/' + 'merge_norm_' + str(i)
  # !crop {parent} {child} {delta_addr} -n -s 10
  i+=1
  print(f"Parent: {parent}, Child: {child}, Delta: {delta_addr}")
# Out:
# Loading weights from model A: yedi-hu/Llama-2-7b-truthfulqa-float16
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.17s/it]
# Loading weights from model B: yedi-hu/slerp_llama_2_child-1-5-float16
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.16s/it]
# Calculating and cropping deltas...
# Processing model.embed_tokens.weight
# Processing model.layers.0.self_attn.q_proj.weight
# Processing model.layers.0.self_attn.k_proj.weight
# Processing model.layers.0.self_attn.v_proj.weight
# Processing model.layers.0.self_attn.o_proj.weight
# Processing model.layers.0.mlp.gate_proj.weight
# Processing model.layers.0.mlp.up_proj.weight
# Processing model.layers.0.mlp.down_proj.weight
# Processing model.layers.0.input_layernorm.weight
# Processing model.layers.0.post_attention_layernorm.weight
# Processing model.layers.1.self_attn.q_proj.weight
# Processing model.layers.1.self_attn.k_proj.weight
# Processing model.layers.1.self_attn.v_proj.weight
# Processing model.layers.1.self_attn.o_proj.weight
# Processing model.layers.1.mlp.gate_proj.weight
# Processing model.layers.1.mlp.up_proj.weight
# Processing model.layers.1.mlp.down_proj.weight
# Processing model.layers.1.input_layernorm.weight
# Processing model.layers.1.post_attention_layernorm.weight
# Processing model.layers.2.self_attn.q_proj.weight
# Processing model.layers.2.self_attn.k_proj.weight
# Processing model.layers.2.self_attn.v_proj.weight
# Processing model.layers.2.self_attn.o_proj.weight
# Processing model.layers.2.mlp.gate_proj.weight
# Processing model.layers.2.mlp.up_proj.weight
# Processing model.layers.2.mlp.down_proj.weight
[00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/yedi-hu/llama2_4tasks_deltas_gen_1_chunks_100/commit/5b3b24d918d61d61bbe846835da63174a84301df', commit_message='Upload model files', commit_description='', oid='5b3b24d918d61d61bbe846835da63174a84301df', pr_url=None, repo_url=RepoUrl('https://huggingface.co/yedi-hu/llama2_4tasks_deltas_gen_1_chunks_100', endpoint='https://huggingface.co', repo_type='model', repo_id='yedi-hu/llama2_4tasks_deltas_gen_1_chunks_100'), pr_revision=None, pr_num=None)

# %%
import torch
t = torch.load('./llama2_4tasks_deltas/merge_norm_10')
print(t.keys())
print(t['model.layers.0.self_attn.k_proj.weight'])
# Out:
# dict_keys(['model.embed_tokens.weight', 'model.layers.0.self_attn.q_proj.weight', 'model.layers.0.self_attn.k_proj.weight', 'model.layers.0.self_attn.v_proj.weight', 'model.layers.0.self_attn.o_proj.weight', 'model.layers.0.mlp.gate_proj.weight', 'model.layers.0.mlp.up_proj.weight', 'model.layers.0.mlp.down_proj.weight', 'model.layers.0.input_layernorm.weight', 'model.layers.0.post_attention_layernorm.weight', 'model.layers.1.self_attn.q_proj.weight', 'model.layers.1.self_attn.k_proj.weight', 'model.layers.1.self_attn.v_proj.weight', 'model.layers.1.self_attn.o_proj.weight', 'model.layers.1.mlp.gate_proj.weight', 'model.layers.1.mlp.up_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.1.input_layernorm.weight', 'model.layers.1.post_attention_layernorm.weight', 'model.layers.2.self_attn.q_proj.weight', 'model.layers.2.self_attn.k_proj.weight', 'model.layers.2.self_attn.v_proj.weight', 'model.layers.2.self_attn.o_proj.weight', 'model.layers.2.mlp.gate_proj.weight', 'model.layers.2.mlp.up_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.2.input_layernorm.weight', 'model.layers.2.post_attention_layernorm.weight', 'model.layers.3.self_attn.q_proj.weight', 'model.layers.3.self_attn.k_proj.weight', 'model.layers.3.self_attn.v_proj.weight', 'model.layers.3.self_attn.o_proj.weight', 'model.layers.3.mlp.gate_proj.weight', 'model.layers.3.mlp.up_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.3.input_layernorm.weight', 'model.layers.3.post_attention_layernorm.weight', 'model.layers.4.self_attn.q_proj.weight', 'model.layers.4.self_attn.k_proj.weight', 'model.layers.4.self_attn.v_proj.weight', 'model.layers.4.self_attn.o_proj.weight', 'model.layers.4.mlp.gate_proj.weight', 'model.layers.4.mlp.up_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.4.input_layernorm.weight', 'model.layers.4.post_attention_layernorm.weight', 'model.layers.5.self_attn.q_proj.weight', 'model.layers.5.self_attn.k_proj.weight', 'model.layers.5.self_attn.v_proj.weight', 'model.layers.5.self_attn.o_proj.weight', 'model.layers.5.mlp.gate_proj.weight', 'model.layers.5.mlp.up_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.5.input_layernorm.weight', 'model.layers.5.post_attention_layernorm.weight', 'model.layers.6.self_attn.q_proj.weight', 'model.layers.6.self_attn.k_proj.weight', 'model.layers.6.self_attn.v_proj.weight', 'model.layers.6.self_attn.o_proj.weight', 'model.layers.6.mlp.gate_proj.weight', 'model.layers.6.mlp.up_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.6.input_layernorm.weight', 'model.layers.6.post_attention_layernorm.weight', 'model.layers.7.self_attn.q_proj.weight', 'model.layers.7.self_attn.k_proj.weight', 'model.layers.7.self_attn.v_proj.weight', 'model.layers.7.self_attn.o_proj.weight', 'model.layers.7.mlp.gate_proj.weight', 'model.layers.7.mlp.up_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.7.input_layernorm.weight', 'model.layers.7.post_attention_layernorm.weight', 'model.layers.8.self_attn.q_proj.weight', 'model.layers.8.self_attn.k_proj.weight', 'model.layers.8.self_attn.v_proj.weight', 'model.layers.8.self_attn.o_proj.weight', 'model.layers.8.mlp.gate_proj.weight', 'model.layers.8.mlp.up_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.8.input_layernorm.weight', 'model.layers.8.post_attention_layernorm.weight', 'model.layers.9.self_attn.q_proj.weight', 'model.layers.9.self_attn.k_proj.weight', 'model.layers.9.self_attn.v_proj.weight', 'model.layers.9.self_attn.o_proj.weight', 'model.layers.9.mlp.gate_proj.weight', 'model.layers.9.mlp.up_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.9.input_layernorm.weight', 'model.layers.9.post_attention_layernorm.weight', 'model.layers.10.self_attn.q_proj.weight', 'model.layers.10.self_attn.k_proj.weight', 'model.layers.10.self_attn.v_proj.weight', 'model.layers.10.self_attn.o_proj.weight', 'model.layers.10.mlp.gate_proj.weight', 'model.l ...
# [0.9846360683441162, 0.9998924136161804, 0.9403793215751648, 1.2880165576934814]

# %% [markdown]
# ## GPT-2

# %%
import pandas as pd

df = pd.read_csv('./gpt2_glue_deltas.csv')
print(df.keys())

for index, row in df.iterrows():
  parent = row['parent']
  child = row['child']
  print(f"Parent: {parent}, Child: {child}")
# Out:
# Index(['parent', 'child', 'change_cola', 'change_mnli', 'change_mrpc',
#        'change_qnli', 'change_qqp', 'change_rte', 'change_sst-2',
#        'change_average'],
#       dtype='object')
# Parent: tanganke/gpt2_cola, Child: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0
# Parent: tanganke/gpt2_mnli, Child: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0
# Parent: tanganke/gpt2_mnli, Child: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1
# Parent: tanganke/gpt2_mrpc, Child: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1
# Parent: tanganke/gpt2_mrpc, Child: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2
# Parent: tanganke/gpt2_qnli, Child: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2
# Parent: tanganke/gpt2_qnli, Child: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3
# Parent: tanganke/gpt2_qqp, Child: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3
# Parent: tanganke/gpt2_qqp, Child: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4
# Parent: tanganke/gpt2_rte, Child: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4
# Parent: tanganke/gpt2_rte, Child: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5
# Parent: tanganke/gpt2_sst2, Child: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5

# %%
import os

if not os.path.exists('./gpt2_glue_merge_deltas/'):
    os.makedirs('./gpt2_glue_merge_deltas/')
i=0
for index, row in df.iterrows():
  parent = row['parent']
  child = row['child']
  delta_addr = './gpt2_glue_merge_deltas/' + 'merge_' + str(i)
  # !crop {parent} {child} {delta_addr}
  i+=1
  print(f"Parent: {parent}, Child: {child}, Delta: {delta_addr}")
# Out:
# Loading weights from model A: tanganke/gpt2_cola
# 2025-06-17 09:38:41.807669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153121.866598    2777 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153121.885373    2777 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:38:41.952288: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge0
# Parent: tanganke/gpt2_cola, Child: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0, Delta: ./gpt2_glue_merge_deltas/merge0
# Loading weights from model A: tanganke/gpt2_mnli
# 2025-06-17 09:39:15.593688: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153155.619026    2953 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153155.626149    2953 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:39:15.651291: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge1
# Parent: tanganke/gpt2_mnli, Child: yedi-hu/slerp_gpt2_cola_gpt2_mnli_0, Delta: ./gpt2_glue_merge_deltas/merge1
# Loading weights from model A: tanganke/gpt2_mnli
# 2025-06-17 09:39:47.028412: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153187.054751    3089 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153187.062867    3089 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:39:47.089886: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1
# config.json: 100% 1.11k/1.11k [00:00<00:00, 5.66MB/s]
# model.safetensors: 100% 249M/249M [00:03<00:00, 80.1MB/s]
# generation_config.json: 100% 144/144 [00:00<00:00, 942kB/s]
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge2
# Parent: tanganke/gpt2_mnli, Child: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1, Delta: ./gpt2_glue_merge_deltas/merge2
# Loading weights from model A: tanganke/gpt2_mrpc
# config.json: 100% 1.05k/1.05k [00:00<00:00, 5.86MB/s]
# 2025-06-17 09:40:21.107032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153221.134072    3230 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153221.140970    3230 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:40:21.164294: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 498M/498M [00:08<00:00, 55.4MB/s]
# Loading weights from model B: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge3
# Parent: tanganke/gpt2_mrpc, Child: yedi-hu/slerp_gpt2_mnli_gpt2_mrpc_1, Delta: ./gpt2_glue_merge_deltas/merge3
# Loading weights from model A: tanganke/gpt2_mrpc
# 2025-06-17 09:40:58.858202: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153258.882940    3453 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153258.889974    3453 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:40:58.914153: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge4
# Parent: tanganke/gpt2_mrpc, Child: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2, Delta: ./gpt2_glue_merge_deltas/merge4
# Loading weights from model A: tanganke/gpt2_qnli
# 2025-06-17 09:41:25.097015: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153285.120851    3565 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153285.128216    3565 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:41:25.151547: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge5
# Parent: tanganke/gpt2_qnli, Child: yedi-hu/slerp_gpt2_mrpc_gpt2_qnli_2, Delta: ./gpt2_glue_merge_deltas/merge5
# Loading weights from model A: tanganke/gpt2_qnli
# 2025-06-17 09:41:46.427979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153306.452473    3661 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153306.459297    3661 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:41:46.482487: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3
# model.safetensors:  61% 249M/406M [00:01<00:01, 79.3MB/s]
# generation_config.json: 100% 144/144 [00:00<00:00, 833kB/s]
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge6
# Parent: tanganke/gpt2_qnli, Child: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3, Delta: ./gpt2_glue_merge_deltas/merge6
# Loading weights from model A: tanganke/gpt2_qqp
# 2025-06-17 09:42:06.970740: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153326.994865    3754 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153327.001848    3754 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:42:07.024861: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 498M/498M [00:13<00:00, 38.0MB/s]
# Loading weights from model B: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge7
# Parent: tanganke/gpt2_qqp, Child: yedi-hu/slerp_gpt2_qnli_gpt2_qqp_3, Delta: ./gpt2_glue_merge_deltas/merge7
# Loading weights from model A: tanganke/gpt2_qqp
# 2025-06-17 09:42:47.800171: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153367.824808    3927 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153367.832015    3927 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:42:47.856903: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4
# config.json: 100% 955/955 [00:00<00:00, 5.08MB/s]
# model.safetensors: 100% 249M/249M [00:03<00:00, 78.7MB/s]
# generation_config.json: 100% 144/144 [00:00<00:00, 917kB/s]
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge8
# Parent: tanganke/gpt2_qqp, Child: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4, Delta: ./gpt2_glue_merge_deltas/merge8
# Loading weights from model A: tanganke/gpt2_rte
# config.json: 100% 1.05k/1.05k [00:00<00:00, 4.39MB/s]
# 2025-06-17 09:43:21.391453: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153401.433947    4076 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153401.446627    4076 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:43:21.483082: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 498M/498M [00:15<00:00, 32.1MB/s]
# Loading weights from model B: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge9
# Parent: tanganke/gpt2_rte, Child: yedi-hu/slerp_gpt2_qqp_gpt2_rte_4, Delta: ./gpt2_glue_merge_deltas/merge9
# Loading weights from model A: tanganke/gpt2_rte
# 2025-06-17 09:44:03.809782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153443.834749    4265 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153443.841788    4265 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:44:03.865680: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Loading weights from model B: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5
# config.json: 100% 955/955 [00:00<00:00, 5.35MB/s]
# model.safetensors: 100% 249M/249M [00:03<00:00, 78.8MB/s]
# generation_config.json: 100% 144/144 [00:00<00:00, 915kB/s]
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge10
# Parent: tanganke/gpt2_rte, Child: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5, Delta: ./gpt2_glue_merge_deltas/merge10
# Loading weights from model A: tanganke/gpt2_sst2
# config.json: 100% 1.05k/1.05k [00:00<00:00, 5.99MB/s]
# 2025-06-17 09:44:27.744630: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750153467.774200    4370 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750153467.781345    4370 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-17 09:44:27.804468: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 498M/498M [00:22<00:00, 22.1MB/s]
# Loading weights from model B: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5
# Calculating and cropping deltas...
# Saving delta weights to ./gpt2_glue_merge_deltas/merge11
# Parent: tanganke/gpt2_sst2, Child: yedi-hu/slerp_gpt2_rte_gpt2_sst2_5, Delta: ./gpt2_glue_merge_deltas/merge11

# %%
user = 'yedi-hu/'
repo_name = user+'gpt2_glue_merge_deltas'
output_path = './gpt2_glue_merge_deltas/'
try:
  api.create_repo(
      repo_id=repo_name,
      private=False,
      exist_ok=True
    )
except Exception as e:
    raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")


api.upload_folder(
    folder_path=output_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)
# Out:
# Uploading model to yedi-hu/gpt2_glue_merge_deltas...
# merge_2:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_1:   0%|          | 0.00/652M [00:00<?, ?B/s]
# Upload 12 LFS files:   0%|          | 0/12 [00:00<?, ?it/s]
# merge_0:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_11:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_10:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_3:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_4:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_5:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_6:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_7:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_8:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_9:   0%|          | 0.00/652M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/yedi-hu/gpt2_glue_merge_deltas/commit/4020d2dfd207ff8a178242caa24d048ade56dd20', commit_message='Upload model files', commit_description='', oid='4020d2dfd207ff8a178242caa24d048ade56dd20', pr_url=None, repo_url=RepoUrl('https://huggingface.co/yedi-hu/gpt2_glue_merge_deltas', endpoint='https://huggingface.co', repo_type='model', repo_id='yedi-hu/gpt2_glue_merge_deltas'), pr_revision=None, pr_num=None)

# %% [markdown]
# ## Task Region Localization (Deltas)

# %%
from huggingface_hub import snapshot_download
local_path = snapshot_download(repo_id="yedi-hu/gpt2_glue_merge_deltas",
                repo_type="model",
                local_dir_use_symlinks=False,
                local_dir="/content/gpt2_glue_merge_deltas/")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/2.05k [00:00<?, ?B/s]
# merge_2:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_1:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_3:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_11:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_10:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_4:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_0:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_5:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_8:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_6:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_7:   0%|          | 0.00/652M [00:00<?, ?B/s]
# merge_9:   0%|          | 0.00/652M [00:00<?, ?B/s]

# %%
import torch
import os
DATA_DIR = "./gpt2_glue_merge_deltas"
delta = torch.load(os.path.join(DATA_DIR, 'merge_1'))
i = 0
for key in delta.keys():
  print(key)
  i+=1
print(f'number of modules: {i}')
# Out:
# transformer.wte.weight
# transformer.wpe.weight
# transformer.h.0.ln_1.weight
# transformer.h.0.ln_1.bias
# transformer.h.0.attn.c_attn.weight
# transformer.h.0.attn.c_attn.bias
# transformer.h.0.attn.c_proj.weight
# transformer.h.0.attn.c_proj.bias
# transformer.h.0.ln_2.weight
# transformer.h.0.ln_2.bias
# transformer.h.0.mlp.c_fc.weight
# transformer.h.0.mlp.c_fc.bias
# transformer.h.0.mlp.c_proj.weight
# transformer.h.0.mlp.c_proj.bias
# transformer.h.1.ln_1.weight
# transformer.h.1.ln_1.bias
# transformer.h.1.attn.c_attn.weight
# transformer.h.1.attn.c_attn.bias
# transformer.h.1.attn.c_proj.weight
# transformer.h.1.attn.c_proj.bias
# transformer.h.1.ln_2.weight
# transformer.h.1.ln_2.bias
# transformer.h.1.mlp.c_fc.weight
# transformer.h.1.mlp.c_fc.bias
# transformer.h.1.mlp.c_proj.weight
# transformer.h.1.mlp.c_proj.bias
# transformer.h.2.ln_1.weight
# transformer.h.2.ln_1.bias
# transformer.h.2.attn.c_attn.weight
# transformer.h.2.attn.c_attn.bias
# transformer.h.2.attn.c_proj.weight
# transformer.h.2.attn.c_proj.bias
# transformer.h.2.ln_2.weight
# transformer.h.2.ln_2.bias
# transformer.h.2.mlp.c_fc.weight
# transformer.h.2.mlp.c_fc.bias
# transformer.h.2.mlp.c_proj.weight
# transformer.h.2.mlp.c_proj.bias
# transformer.h.3.ln_1.weight
# transformer.h.3.ln_1.bias
# transformer.h.3.attn.c_attn.weight
# transformer.h.3.attn.c_attn.bias
# transformer.h.3.attn.c_proj.weight
# transformer.h.3.attn.c_proj.bias
# transformer.h.3.ln_2.weight
# transformer.h.3.ln_2.bias
# transformer.h.3.mlp.c_fc.weight
# transformer.h.3.mlp.c_fc.bias
# transformer.h.3.mlp.c_proj.weight
# transformer.h.3.mlp.c_proj.bias
# transformer.h.4.ln_1.weight
# transformer.h.4.ln_1.bias
# transformer.h.4.attn.c_attn.weight
# transformer.h.4.attn.c_attn.bias
# transformer.h.4.attn.c_proj.weight
# transformer.h.4.attn.c_proj.bias
# transformer.h.4.ln_2.weight
# transformer.h.4.ln_2.bias
# transformer.h.4.mlp.c_fc.weight
# transformer.h.4.mlp.c_fc.bias
# transformer.h.4.mlp.c_proj.weight
# transformer.h.4.mlp.c_proj.bias
# transformer.h.5.ln_1.weight
# transformer.h.5.ln_1.bias
# transformer.h.5.attn.c_attn.weight
# transformer.h.5.attn.c_attn.bias
# transformer.h.5.attn.c_proj.weight
# transformer.h.5.attn.c_proj.bias
# transformer.h.5.ln_2.weight
# transformer.h.5.ln_2.bias
# transformer.h.5.mlp.c_fc.weight
# transformer.h.5.mlp.c_fc.bias
# transformer.h.5.mlp.c_proj.weight
# transformer.h.5.mlp.c_proj.bias
# transformer.h.6.ln_1.weight
# transformer.h.6.ln_1.bias
# transformer.h.6.attn.c_attn.weight
# transformer.h.6.attn.c_attn.bias
# transformer.h.6.attn.c_proj.weight
# transformer.h.6.attn.c_proj.bias
# transformer.h.6.ln_2.weight
# transformer.h.6.ln_2.bias
# transformer.h.6.mlp.c_fc.weight
# transformer.h.6.mlp.c_fc.bias
# transformer.h.6.mlp.c_proj.weight
# transformer.h.6.mlp.c_proj.bias
# transformer.h.7.ln_1.weight
# transformer.h.7.ln_1.bias
# transformer.h.7.attn.c_attn.weight
# transformer.h.7.attn.c_attn.bias
# transformer.h.7.attn.c_proj.weight
# transformer.h.7.attn.c_proj.bias
# transformer.h.7.ln_2.weight
# transformer.h.7.ln_2.bias
# transformer.h.7.mlp.c_fc.weight
# transformer.h.7.mlp.c_fc.bias
# transformer.h.7.mlp.c_proj.weight
# transformer.h.7.mlp.c_proj.bias
# transformer.h.8.ln_1.weight
# transformer.h.8.ln_1.bias
# transformer.h.8.attn.c_attn.weight
# transformer.h.8.attn.c_attn.bias
# transformer.h.8.attn.c_proj.weight
# transformer.h.8.attn.c_proj.bias
# transformer.h.8.ln_2.weight
# transformer.h.8.ln_2.bias
# transformer.h.8.mlp.c_fc.weight
# transformer.h.8.mlp.c_fc.bias
# transformer.h.8.mlp.c_proj.weight
# transformer.h.8.mlp.c_proj.bias
# transformer.h.9.ln_1.weight
# transformer.h.9.ln_1.bias
# transformer.h.9.attn.c_attn.weight
# transformer.h.9.attn.c_attn.bias
# transformer.h.9.attn.c_proj.weight
# transformer.h.9.attn.c_proj.bias
# transformer.h.9.ln_2.weight
# transformer.h.9.ln_2.bias
# transformer.h.9.mlp.c_fc.weight
# transformer.h.9.mlp.c_fc.bias
# transformer.h.9.mlp.c_proj.weight
# transformer.h.9.mlp.c_proj.bias
# transformer.h.10.ln_1.weight
# transformer.h.10.ln_1.bias
# transformer.h.10.attn.c_attn.weight
# transformer.h.10.attn.c_attn.bias
# transformer.h.10.attn.c_proj.weight
# transformer.h.10.attn.c_proj.bias
# transformer.h.10.ln_2.weight
# transformer.h.10.ln_2.bias
# transformer.h.10.mlp.c_fc.weight
# transformer.h.10.mlp.c_fc.bias
# transformer.h.10.mlp.c_proj.weight
# transformer.h.10.mlp.c_proj.bias
# transformer.h.11.ln_1.weight
# transformer.h.11.ln_1.bias
# transformer.h.11.attn.c_attn.weight
# transformer.h.11.attn.c_attn.bias
# transformer.h.11.attn.c_proj.weight
# transformer.h.11.attn.c_proj.bias
# transformer.h.11.ln_2.weight
# transformer.h.11.ln_2.bias
# transformer.h.11.mlp.c_fc.weight
# transformer.h.11.mlp.c_fc.bias
# transformer.h.11.mlp.c_proj.weight
# transformer.h.11.mlp.c_proj.bias
# transformer.ln_f.weight
# transformer.ln_f.bias
# lm_head.weight
# number of modules: 149

# %%
import os
import torch
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from sklearn.linear_model import LassoCV, ElasticNetCV, ElasticNet
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state
from sklearn.exceptions import ConvergenceWarning
import warnings

# --- reproducibility ---
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# --- configs ---
DATA_DIR = "./gpt2_glue_merge_deltas"
METRIC_CSV = "./gpt2_glue_merges_deltas/gpt2_glue_deltas.csv"
USE_ELASTICNET = True
ALPHA_LIST = np.logspace(-4, 0, 20)

# For optional stability selection
REPEAT_SELECTION = True
N_REPEATS = 100
SELECTION_THRESHOLD = 50
MANUAL_ALPHA = 1e-3
L1_RATIO = 0.7


# --- extract features ---
def extract_features_and_labels(data_dir, metric_csv, task):
    metric_table = pd.read_csv(metric_csv)
    metric_map = dict(zip(metric_table["delta"], metric_table[task]))

    feature_names_set = set()
    raw_data = []

    for fname in os.listdir(data_dir):
        match_keys = [k for k in metric_map if fname in k or k.endswith(fname)]
        if not match_keys:
            print(f"Warning: Cannot match {fname} to any child name in CSV, skipping.")
            continue

        child_name = match_keys[0]
        delta_metric = metric_map[child_name]

        delta = torch.load(os.path.join(data_dir, fname))

        feature_dict = {
            key: tensor.norm().item()
            for key, tensor in delta.items()
            if isinstance(tensor, torch.Tensor) and tensor.numel() > 0
        }
        feature_names_set.update(feature_dict.keys())
        raw_data.append((feature_dict, delta_metric))

    feature_names = sorted(feature_names_set)
    X, y = [], []

    for feature_dict, delta_metric in raw_data:
        x = [feature_dict.get(k, 0.0) for k in feature_names]
        X.append(x)
        y.append(delta_metric)

    return np.array(X), np.array(y), feature_names


# --- generate mask dictionary from selection ---
def generate_mask_dict(feature_names, selected_mask):
    return {name: bool(mask) for name, mask in zip(feature_names, selected_mask)}


# --- train ---
def train_and_interpret(X, y, feature_names, task):
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    rng = check_random_state(SEED)

    if REPEAT_SELECTION:
        print(f"[Info] Using repeated ElasticNet selection over {N_REPEATS} bootstraps")
        selection_counts = np.zeros(len(feature_names))

        for _ in range(N_REPEATS):
            idx = rng.choice(len(X), len(X), replace=True)
            X_sample, y_sample = X_scaled[idx], y[idx]

            model = ElasticNet(alpha=MANUAL_ALPHA, l1_ratio=L1_RATIO, max_iter=10000)
            model.fit(X_sample, y_sample)

            selection_counts += (model.coef_ != 0)

        selected_mask = selection_counts >= SELECTION_THRESHOLD
        coef = selection_counts  # for plotting
    else:
        if USE_ELASTICNET:
            model = ElasticNetCV(
                cv=5, alphas=ALPHA_LIST, l1_ratio=0.5,
                max_iter=10000, random_state=rng
            ).fit(X_scaled, y)
        else:
            model = LassoCV(
                cv=5, alphas=ALPHA_LIST,
                max_iter=10000, random_state=rng
            ).fit(X_scaled, y)

        coef = model.coef_
        selected_mask = coef != 0

    selected_features = np.array(feature_names)[selected_mask]
    selected_importance = coef[selected_mask]

    # --- visualization ---
    plt.figure(figsize=(10, 4))
    plt.bar(np.arange(len(selected_importance)), selected_importance)
    plt.xticks(np.arange(len(selected_importance)), selected_features, rotation=90, fontsize=8)
    plt.title(f"Feature Importance for {task}")
    plt.tight_layout()
    plt.savefig(f"feature_importance_{task}.png")
    plt.show()

    # --- save mask dict ---
    mask_dict = generate_mask_dict(feature_names, selected_mask)
    torch.save(mask_dict, f"parameter_mask_{task}.pt")
    print(f"[Info] Saved parameter mask to parameter_mask_{task}.pt")

    return selected_features, selected_importance

# %%
metric_table = pd.read_csv(METRIC_CSV)
all_tasks = [col for col in metric_table.columns if col.startswith("change_")]
task_features_list = {}

# --- main ---
for task in all_tasks:
  X, y, feature_names = extract_features_and_labels(DATA_DIR, METRIC_CSV, task)
  selected_features, selected_importance = train_and_interpret(X, y, feature_names, task)
  task_features_list[task] = (selected_features, selected_importance)
# Out:
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
import pandas as pd
import numpy as np

all_features = sorted({feat for task_feats, _ in task_features_list.values() for feat in task_feats})

task_weight_vectors = {}
for task, (feats, imps) in task_features_list.items():
    weight_vec = np.zeros(len(all_features))
    for f, imp in zip(feats, imps):
        idx = all_features.index(f)
        weight_vec[idx] = imp
    task_weight_vectors[task] = weight_vec

def jaccard_similarity(a, b):
    return len(set(a) & set(b)) / len(set(a) | set(b))

jaccard_matrix = pd.DataFrame(index=task_features_list.keys(), columns=task_features_list.keys())
for task1 in task_features_list:
    for task2 in task_features_list:
        f1, _ = task_features_list[task1]
        f2, _ = task_features_list[task2]
        jaccard_matrix.loc[task1, task2] = jaccard_similarity(f1, f2)

print("Jaccard Similarity Matrix:")
print(jaccard_matrix.astype(float).round(3))


task_names = list(task_weight_vectors.keys())
weight_matrix = np.stack([task_weight_vectors[task] for task in task_names])
cosine_sim_matrix = cosine_similarity(weight_matrix)

cosine_matrix_df = pd.DataFrame(cosine_sim_matrix, index=task_names, columns=task_names)
print("\nCosine Similarity Matrix:")
print(cosine_matrix_df.round(3))
# Out:
# Jaccard Similarity Matrix:
#                 change_cola  change_mnli  change_mrpc  change_qnli  \
# change_cola           1.000        0.347        0.438        0.312
# change_mnli           0.347        1.000        0.333        0.129
# change_mrpc           0.438        0.333        1.000        0.289
# change_qnli           0.312        0.129        0.289        1.000
# change_qqp            0.315        0.128        0.302        0.926
# change_rte            0.278        0.414        0.457        0.143
# change_sst-2          0.413        0.298        0.776        0.277
# change_average        0.339        0.424        0.622        0.177
#
#                 change_qqp  change_rte  change_sst-2  change_average
# change_cola          0.315       0.278         0.413           0.339
# change_mnli          0.128       0.414         0.298           0.424
# change_mrpc          0.302       0.457         0.776           0.622
# change_qnli          0.926       0.143         0.277           0.177
# change_qqp           1.000       0.148         0.282           0.188
# change_rte           0.148       1.000         0.455           0.613
# change_sst-2         0.282       0.455         1.000           0.628
# change_average       0.188       0.613         0.628           1.000
#
# Cosine Similarity Matrix:
#                 change_cola  change_mnli  change_mrpc  change_qnli  \
# change_cola           1.000        0.494        0.395        0.090
# change_mnli           0.494        1.000        0.083        0.160
# change_mrpc           0.395        0.083        1.000       -0.147
# change_qnli           0.090        0.160       -0.147        1.000
# change_qqp           -0.144       -0.308        0.286       -0.220
# change_rte            0.185        0.307        0.614       -0.042
# change_sst-2          0.273        0.190        0.891        0.064
# change_average        0.593        0.319        0.812       -0.014
#
#                 change_qqp  change_rte  change_sst-2  change_average
# change_cola         -0.144       0.185         0.273           0.593
# change_mnli         -0.308       0.307         0.190           0.319
# change_mrpc          0.286       0.614         0.891           0.812
# change_qnli         -0.220      -0.042         0.064          -0.014
# change_qqp           1.000      -0.050         0.142           0.046
# change_rte          -0.050       1.000         0.728           0.750
# change_sst-2         0.142       0.728         1.000           0.802
# change_average       0.046       0.750         0.802           1.000

# %%
# prompt: visualize two matrix and remove change_average

import matplotlib.pyplot as plt
import seaborn as sns

tasks_to_visualize = [task for task in task_names if task != "change_average"]

# Filter the cosine similarity matrix
cosine_matrix_filtered = cosine_matrix_df.loc[tasks_to_visualize, tasks_to_visualize]

# Visualize the Cosine Similarity Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cosine_matrix_filtered.astype(float), annot=True, fmt=".2f", cmap="viridis")
plt.title("Cosine Similarity Matrix")
plt.show()


# Filter the Jaccard similarity matrix
jaccard_matrix_filtered = jaccard_matrix.loc[tasks_to_visualize, tasks_to_visualize]

# Visualize the Jaccard Similarity Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(jaccard_matrix_filtered.astype(float), annot=True, fmt=".2f", cmap="viridis")
plt.title("Jaccard Similarity Matrix")
plt.show()

# %%
import torch
from typing import Dict, Optional
import logging

logger = logging.getLogger(__name__)

def generate_task_mask(
    task_name: str,
    task_features_list: Dict[str, tuple],
    base_model_path: str,
    save_path: Optional[str] = None,
    top_percentile: float = 0.25  # NEW: keep top X% important parameters
) -> Dict[str, torch.Tensor]:
    """
    Generate a boolean mask for a specific task based on top-percentile of important parameter names.

    Args:
        task_name (str): Name of the task (e.g., "change_cola")
        task_features_list (Dict[str, tuple]): Mapping from task name to (selected feature names, importance values)
        base_model_path (str): Path to the base model used to obtain parameter shapes
        save_path (Optional[str]): If specified, save the mask dict to this path
        top_percentile (float): Percentile of most important parameters to keep (e.g., 0.1 = top 10%)

    Returns:
        Dict[str, torch.Tensor]: Dictionary of boolean masks for the specified task
    """
    if task_name not in task_features_list:
        raise ValueError(f"Task '{task_name}' not found in task_features_list.")

    logger.info(f"Loading base model weights from: {base_model_path}")
    state_dict = torch.load(base_model_path, map_location="cpu")

    selected_features, importance_values = task_features_list[task_name]

    # Sort and select top percentile
    zipped = list(zip(selected_features, importance_values))
    zipped.sort(key=lambda x: -x[1])  # descending sort
    # Only keep top_p% of the whole modules
    cutoff_index = int(len(state_dict) * top_percentile)
    cutoff_index = max(1, min(cutoff_index,len(zipped)))  # at least one selected
    top_selected_features = [name for name, _ in zipped[:cutoff_index]]
    selected_features_set = set(top_selected_features)

    logger.info(f"Generating mask for task: {task_name} with top {top_percentile*100:.1f}% ({cutoff_index}) selected features.")
    mask_dict: Dict[str, torch.Tensor] = {}
    num_masked_keys = 0

    for key, tensor in state_dict.items():
        if not isinstance(tensor, torch.Tensor):
            continue

        if key in selected_features_set:
            mask = torch.ones_like(tensor, dtype=torch.bool)
            num_masked_keys += 1
        else:
            mask = torch.zeros_like(tensor, dtype=torch.bool)

        mask_dict[key] = mask

    print(f"Masked keys (with any True): {num_masked_keys} out of {len(state_dict)} parameters")

    if save_path:
        torch.save(mask_dict, save_path)
        logger.info(f"Task mask saved to: {save_path}")

    return mask_dict

# %%
mask = generate_task_mask(
    task_name="change_mnli",
    task_features_list=task_features_list,
    base_model_path="gpt2_glue_merge_deltas/merge_0",
    save_path="mnli_mask"
)
# Out:
# Masked keys (with any True): 19 out of 149 parameters

# %%
# !slerp_merge \
tanganke/gpt2_cola\
tanganke/gpt2_mnli\
./slerp_gpt2_cola_gpt2_mnli_mask_25\
-m mnli_mask
# Out:
# INFO:methods.slerp:Loading weights from model A: tanganke/gpt2_cola
# config.json: 100% 1.05k/1.05k [00:00<00:00, 4.40MB/s]
# 2025-06-19 12:02:31.880398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750334552.210798    6566 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750334552.301770    6566 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-19 12:02:32.995115: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 498M/498M [00:19<00:00, 25.9MB/s]
# INFO:methods.slerp:Loading weights from model B: tanganke/gpt2_mnli
# config.json: 100% 1.20k/1.20k [00:00<00:00, 5.43MB/s]
# model.safetensors: 100% 498M/498M [00:27<00:00, 18.4MB/s]
# INFO:methods.slerp:Loading masks from: mnli_mask
# INFO:methods.slerp:Performing SLERP on model weights...
# INFO:methods.slerp:transformer.wte.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.wpe.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.ln_1.weight: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.0.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.attn.c_attn.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.0.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.ln_2.weight: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.0.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.0.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.attn.c_attn.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.1.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.1.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.ln_1.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.2.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.attn.c_attn.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.2.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.2.mlp.c_proj.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.3.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.attn.c_attn.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.3.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.attn.c_proj.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.3.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.ln_2.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.3.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.3.mlp.c_proj.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.4.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.4.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.ln_2.weight: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.5.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.5.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.6.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.ln_2.weight: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.7.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.7.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.ln_1.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.8.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.8.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.ln_1.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.9.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.9.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.attn.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.ln_2.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.10.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.ln_1.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.ln_1.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.attn.c_attn.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.attn.c_attn.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.attn.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.attn.c_proj.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.11.ln_2.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.ln_2.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.h.11.mlp.c_fc.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.mlp.c_fc.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.mlp.c_proj.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.h.11.mlp.c_proj.bias: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:transformer.ln_f.weight: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:transformer.ln_f.bias: Applied SLERP to 100.00% of parameters
# INFO:methods.slerp:lm_head.weight: Applied SLERP to 0.00% of parameters
# INFO:methods.slerp:Saving merged model to ./slerp_gpt2_cola_gpt2_mnli_mask_25
# tokenizer_config.json: 100% 524/524 [00:00<00:00, 2.68MB/s]
# vocab.json: 100% 999k/999k [00:00<00:00, 15.2MB/s]
# merges.txt: 100% 456k/456k [00:00<00:00, 8.77MB/s]
# special_tokens_map.json: 100% 470/470 [00:00<00:00, 2.82MB/s]

# %%
# !replace_merge \
tanganke/gpt2_cola\
tanganke/gpt2_mnli\
mnli_mask\
./replace_gpt2_cola_gpt2_mnli_mask_25
# Out:
# INFO:methods.replace_merge:Loading weights from model A: tanganke/gpt2_cola
# 2025-06-19 12:04:03.767671: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750334643.792024    7035 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750334643.799327    7035 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-19 12:04:03.823784: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO:methods.replace_merge:Loading weights from model B: tanganke/gpt2_mnli
# INFO:methods.replace_merge:Loading masks from: mnli_mask
# INFO:methods.replace_merge:Performing model weights replacements...
# INFO:methods.replace_merge:transformer.wte.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.wpe.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.ln_1.weight: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.attn.c_attn.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.ln_2.weight: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.0.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.attn.c_attn.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.1.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.ln_1.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.attn.c_attn.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.2.mlp.c_proj.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.attn.c_attn.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.attn.c_proj.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.ln_2.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.3.mlp.c_proj.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.4.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.ln_2.weight: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.5.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.6.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.ln_2.weight: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.7.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.ln_1.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.8.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.ln_1.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.9.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.attn.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.ln_2.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.10.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.ln_1.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.ln_1.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.attn.c_attn.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.attn.c_attn.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.attn.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.attn.c_proj.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.ln_2.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.ln_2.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.mlp.c_fc.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.mlp.c_fc.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.mlp.c_proj.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.h.11.mlp.c_proj.bias: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:transformer.ln_f.weight: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:transformer.ln_f.bias: Applied replace to 100.00% of parameters
# INFO:methods.replace_merge:lm_head.weight: Applied replace to 0.00% of parameters
# INFO:methods.replace_merge:Saving merged model to ./replace_gpt2_cola_gpt2_mnli_mask_25
# Successfully replaced masked areas, saved to: ./replace_gpt2_cola_gpt2_mnli_mask_25

# %%
from huggingface_hub import HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'replace_gpt2_cola_gpt2_mnli_mask_25' # @param {"type":"string"}'
repo_name=f'yedi-hu/{model_name}'
model_path=f'./{model_name}'
token='yours'

api = HfApi()

try:
    api.create_repo(
        repo_id=repo_name,
        private=False,
        exist_ok=True
      )
except Exception as e:
      raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")

  # Load the model and tokenizer
# model = AutoModelForCausalLM.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

api.upload_folder(
    folder_path=model_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)


print(f"✅ Model successfully uploaded to: https://huggingface.co/{repo_name}")

# %% [markdown]
# ## Task Region Localization (Norms)

# %%
from huggingface_hub import snapshot_download
local_path = snapshot_download(repo_id="yedi-hu/llama2_4tasks_deltas_gen_1_chunks_10",
                repo_type="model",
                local_dir_use_symlinks=False,
                local_dir="/content/llama2_4tasks_deltas_gen_1_chunks_10/")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:980: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# merge_norm_11:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_3:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_2:   0%|          | 0.00/171k [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# merge_norm_0:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_1:   0%|          | 0.00/171k [00:00<?, ?B/s]
# llama2_4tasks_deltas_gen_1.csv: 0.00B [00:00, ?B/s]
# merge_norm_10:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_8:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_4:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_6:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm_9:   0%|          | 0.00/171k [00:00<?, ?B/s]
# merge_norm
# model.norm.weight
# [np.float64(0.00030118990889137253), np.float64(0.00029336546709782827), np.float64(0.00028532652881774423), np.float64(0.00033067412632479306), np.float64(0.00028532652881774423), np.float64(0.0002943548830236778), np.float64(0.0002893739052684345), np.float64(0.00028532652881774423), np.float64(0.0002685276156603337), np.float64(0.0003427062530098869)]
# lm_head.weight
# [np.float64(0.00034858492779581325), np.float64(0.0004062317079005187), np.float64(0.0004187171849362647), np.float64(0.0004172706589972553), np.float64(0.0004063493898040952), np.float64(0.00040596038756322985), np.float64(0.0004004313137286577), np.float64(0.00039516743576745026), np.float64(0.0003848536738829043), np.float64(0.0003102447628860879)]
# number of modules: 291

# %%
import os
import torch
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt

from sklearn.linear_model import LassoCV, ElasticNetCV, ElasticNet, Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.utils import check_random_state
from sklearn.exceptions import ConvergenceWarning
import warnings
import joblib

# --- reproducibility ---
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

warnings.filterwarnings("ignore", category=ConvergenceWarning)

# --- configs ---
DATA_DIR = "./llama2_4tasks_deltas_gen_1_chunks_10"
METRIC_CSV = "./llama2_4tasks_deltas_gen_1_chunks_10/llama2_4tasks_deltas_gen_1.csv"
USE_ELASTICNET = True
ALPHA_LIST = np.logspace(-3, 0, 20)

# For optional stability selection
REPEAT_SELECTION = True
N_REPEATS = 100
SELECTION_THRESHOLD = 70
MANUAL_ALPHA = 1e-3
L1_RATIO = 0.9


# --- extract features ---
def extract_features_and_labels(data_dir, metric_csv, task):
    metric_table = pd.read_csv(metric_csv)
    metric_map = dict(zip(metric_table["delta_norm"], metric_table[task]))

    feature_names_set = set()
    raw_data = []

    for fname in os.listdir(data_dir):
        match_keys = [k for k in metric_map if fname in k or k.endswith(fname)]
        if not match_keys:
            print(f"Warning: Cannot match {fname} to any child name in CSV, skipping.")
            continue

        child_name = match_keys[0]
        delta_metric = metric_map[child_name]

        delta = torch.load(os.path.join(data_dir, fname), weights_only=False)

        feature_dict = {}
        for key, value in delta.items():
            if isinstance(value, list):
                # Handle chunked norm list
                for i, v in enumerate(value):
                    feature_name = f"{key}[{i}]"
                    feature_dict[feature_name] = v
                    feature_names_set.add(feature_name)
            else:
                # Handle normal scalar norm
                feature_dict[key] = value
                feature_names_set.add(key)

        raw_data.append((feature_dict, delta_metric))

    feature_names = sorted(feature_names_set)
    X, y = [], []

    for feature_dict, delta_metric in raw_data:
        x = [feature_dict.get(k, 0.0) for k in feature_names]
        X.append(x)
        y.append(delta_metric)

    return np.array(X), np.array(y), feature_names


# --- generate mask dictionary from selection ---
def generate_mask_dict(feature_names, selected_mask):
    return {name: bool(mask) for name, mask in zip(feature_names, selected_mask)}

def save_checkpoint(scaler, model, feature_names, task, checkpoint_dir="./checkpoints"):
    os.makedirs(checkpoint_dir, exist_ok=True)
    scaler_path = os.path.join(checkpoint_dir, f"{task}_scaler.pkl")
    model_path = os.path.join(checkpoint_dir, f"{task}_model.pkl")
    features_path = os.path.join(checkpoint_dir, f"{task}_features.pkl")

    joblib.dump(scaler, scaler_path)
    joblib.dump(model, model_path)
    joblib.dump(feature_names, features_path)
    print(f"[Info] Saved checkpoint to {checkpoint_dir}")


def load_checkpoint(task, checkpoint_dir="./checkpoints"):
    scaler_path = os.path.join(checkpoint_dir, f"{task}_scaler.pkl")
    model_path = os.path.join(checkpoint_dir, f"{task}_model.pkl")
    features_path = os.path.join(checkpoint_dir, f"{task}_features.pkl")

    scaler = joblib.load(scaler_path)
    model = joblib.load(model_path)
    feature_names = joblib.load(features_path)

    print(f"[Info] Loaded checkpoint from {checkpoint_dir}")
    return scaler, model, feature_names


def load_checkpoint_and_extract_features(task, checkpoint_dir="./checkpoints", plot=True):
    # --- Load checkpoint ---
    scaler_path = os.path.join(checkpoint_dir, f"{task}_scaler.pkl")
    model_path = os.path.join(checkpoint_dir, f"{task}_model.pkl")
    features_path = os.path.join(checkpoint_dir, f"{task}_features.pkl")

    scaler = joblib.load(scaler_path)
    model = joblib.load(model_path)
    feature_names = joblib.load(features_path)

    # --- Extract selected features ---
    coef = model.coef_
    selected_mask = coef != 0
    selected_features = np.array(feature_names)[selected_mask]
    selected_importance = coef[selected_mask]

    # --- Optional: Plot feature importance ---
    if plot:
        plt.figure(figsize=(10, 4))
        plt.bar(np.arange(len(selected_importance)), selected_importance)
        plt.xticks(np.arange(len(selected_importance)), selected_features, rotation=90, fontsize=8)
        plt.title(f"Feature Importance for {task} (From Checkpoint)")
        plt.tight_layout()
        plt.savefig(f"feature_importance_{task}_from_checkpoint.png")
        plt.show()

    return selected_features, selected_importance

# %%
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
import numpy as np
import os
import matplotlib.pyplot as plt


def train_and_interpret_elasticnet(X, y, feature_names, task,
                                   resume=False,
                                   checkpoint_dir="./checkpoints",
                                   n_bootstraps=150,
                                   sample_fraction=0.85,
                                   elastic_alpha=0.001,
                                   elastic_l1_ratio=0.7,
                                   selection_threshold=0.2,
                                   random_seed=42):
    """
    Feature selection via ElasticNet with stability selection.

    Parameters:
    - n_bootstraps: number of bootstrap iterations for stability selection.
    - sample_fraction: fraction of data used per bootstrap sample (usually < 1).
    - elastic_alpha: ElasticNet regularization strength.
    - elastic_l1_ratio: ElasticNet L1/L2 mixing ratio (0 = Ridge, 1 = Lasso).
    - selection_threshold: selection frequency threshold to consider a feature important (0-1).
    """

    if resume:
        scaler, model, feature_names = load_checkpoint(task, checkpoint_dir)
        X_scaled = scaler.transform(X)
        print("[Info] Continuing from checkpoint - skipping training.")
    else:
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)
        rng = np.random.RandomState(random_seed)

        n_samples, n_features = X.shape
        selection_counts = np.zeros(n_features, dtype=int)

        # Bootstrap resampling + ElasticNet fitting
        for i in range(n_bootstraps):
            sample_idx = rng.choice(n_samples, size=int(n_samples * sample_fraction), replace=True)
            X_sample = X_scaled[sample_idx]
            y_sample = y[sample_idx]

            model = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, max_iter=10000)
            model.fit(X_sample, y_sample)

            # Count how many times each feature is selected (non-zero coefficient)
            selection_counts += (model.coef_ != 0)

            if (i + 1) % 10 == 0:
                print(f"[Info] Bootstrap iteration {i + 1}/{n_bootstraps} done.")

        # Calculate feature selection frequency
        selection_freq = selection_counts / n_bootstraps
        selected_mask = selection_freq >= selection_threshold

        if np.sum(selected_mask) == 0:
            print("[Warning] No features passed stability threshold. Using all features.")
            selected_mask = np.ones(n_features, dtype=bool)

        # Final ElasticNet on selected features
        model = ElasticNet(alpha=elastic_alpha, l1_ratio=elastic_l1_ratio, max_iter=10000)
        model.fit(X_scaled[:, selected_mask], y)

        coef = np.zeros(n_features)
        coef[selected_mask] = model.coef_

        save_checkpoint(scaler, model, feature_names, task, checkpoint_dir)

    selected_features = np.array(feature_names)[coef != 0]
    print(f"[Info] Selected {len(selected_features)} features out of {len(feature_names)}.")
    selected_importance = coef[coef != 0]

    # Visualization
    plt.figure(figsize=(10, 4))
    plt.bar(np.arange(len(selected_importance)), selected_importance)
    plt.xticks(np.arange(len(selected_importance)), selected_features, rotation=90, fontsize=8)
    plt.title(f"Feature Importance for {task} (ElasticNet Stability Selection)")
    plt.tight_layout()
    plt.savefig(f"feature_importance_{task}.png")
    plt.show()

    return selected_features, selected_importance


# --- Main ---
metric_table = pd.read_csv(METRIC_CSV)
all_tasks = [col for col in metric_table.columns if col.startswith("change_")]
task_features_list = {}

for task in all_tasks:
    X, y, feature_names = extract_features_and_labels(DATA_DIR, METRIC_CSV, task)
    selected_features, selected_importance = train_and_interpret_elasticnet(X, y, feature_names, task)
    task_features_list[task] = (selected_features, selected_importance)
# Out:
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match llama2_4tasks_deltas_gen_1.csv to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# [Info] Bootstrap iteration 10/150 done.
# [Info] Bootstrap iteration 20/150 done.
# [Info] Bootstrap iteration 30/150 done.
# [Info] Bootstrap iteration 40/150 done.
# [Info] Bootstrap iteration 50/150 done.
# [Info] Bootstrap iteration 60/150 done.
# [Info] Bootstrap iteration 70/150 done.
# [Info] Bootstrap iteration 80/150 done.
# [Info] Bootstrap iteration 90/150 done.
# [Info] Bootstrap iteration 100/150 done.
# [Info] Bootstrap iteration 110/150 done.
# [Info] Bootstrap iteration 120/150 done.
# [Info] Bootstrap iteration 130/150 done.
# [Info] Bootstrap iteration 140/150 done.
# [Info] Bootstrap iteration 150/150 done.
# [Info] Saved checkpoint to ./checkpoints
# [Info] Selected 701 features out of 2910.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match llama2_4tasks_deltas_gen_1.csv to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# [Info] Bootstrap iteration 10/150 done.
# [Info] Bootstrap iteration 20/150 done.
# [Info] Bootstrap iteration 30/150 done.
# [Info] Bootstrap iteration 40/150 done.
# [Info] Bootstrap iteration 50/150 done.
# [Info] Bootstrap iteration 60/150 done.
# [Info] Bootstrap iteration 70/150 done.
# [Info] Bootstrap iteration 80/150 done.
# [Info] Bootstrap iteration 90/150 done.
# [Info] Bootstrap iteration 100/150 done.
# [Info] Bootstrap iteration 110/150 done.
# [Info] Bootstrap iteration 120/150 done.
# [Info] Bootstrap iteration 130/150 done.
# [Info] Bootstrap iteration 140/150 done.
# [Info] Bootstrap iteration 150/150 done.
# [Info] Saved checkpoint to ./checkpoints
# [Info] Selected 1655 features out of 2910.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match llama2_4tasks_deltas_gen_1.csv to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# [Info] Bootstrap iteration 10/150 done.
# [Info] Bootstrap iteration 20/150 done.
# [Info] Bootstrap iteration 30/150 done.
# [Info] Bootstrap iteration 40/150 done.
# [Info] Bootstrap iteration 50/150 done.
# [Info] Bootstrap iteration 60/150 done.
# [Info] Bootstrap iteration 70/150 done.
# [Info] Bootstrap iteration 80/150 done.
# [Info] Bootstrap iteration 90/150 done.
# [Info] Bootstrap iteration 100/150 done.
# [Info] Bootstrap iteration 110/150 done.
# [Info] Bootstrap iteration 120/150 done.
# [Info] Bootstrap iteration 130/150 done.
# [Info] Bootstrap iteration 140/150 done.
# [Info] Bootstrap iteration 150/150 done.
# [Info] Saved checkpoint to ./checkpoints
# [Info] Selected 1509 features out of 2910.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match llama2_4tasks_deltas_gen_1.csv to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# [Info] Bootstrap iteration 10/150 done.
# [Info] Bootstrap iteration 20/150 done.
# [Info] Bootstrap iteration 30/150 done.
# [Info] Bootstrap iteration 40/150 done.
# [Info] Bootstrap iteration 50/150 done.
# [Info] Bootstrap iteration 60/150 done.
# [Info] Bootstrap iteration 70/150 done.
# [Info] Bootstrap iteration 80/150 done.
# [Info] Bootstrap iteration 90/150 done.
# [Info] Bootstrap iteration 100/150 done.
# [Info] Bootstrap iteration 110/150 done.
# [Info] Bootstrap iteration 120/150 done.
# [Info] Bootstrap iteration 130/150 done.
# [Info] Bootstrap iteration 140/150 done.
# [Info] Bootstrap iteration 150/150 done.
# [Info] Saved checkpoint to ./checkpoints
# [Info] Selected 1070 features out of 2910.
# Warning: Cannot match .gitattributes to any child name in CSV, skipping.
# Warning: Cannot match llama2_4tasks_deltas_gen_1.csv to any child name in CSV, skipping.
# Warning: Cannot match .cache to any child name in CSV, skipping.
# [Info] Bootstrap iteration 10/150 done.
# [Info] Bootstrap iteration 20/150 done.
# [Info] Bootstrap iteration 30/150 done.
# [Info] Bootstrap iteration 40/150 done.
# [Info] Bootstrap iteration 50/150 done.
# [Info] Bootstrap iteration 60/150 done.
# [Info] Bootstrap iteration 70/150 done.
# [Info] Bootstrap iteration 80/150 done.
# [Info] Bootstrap iteration 90/150 done.
# [Info] Bootstrap iteration 100/150 done.
# [Info] Bootstrap iteration 110/150 done.
# [Info] Bootstrap iteration 120/150 done.
# [Info] Bootstrap iteration 130/150 done.
# [Info] Bootstrap iteration 140/150 done.
# [Info] Bootstrap iteration 150/150 done.
# [Info] Saved checkpoint to ./checkpoints
# [Info] Selected 235 features out of 2910.

# %% [markdown]
# ## Other ML methods

# %%
from sklearn.feature_selection import mutual_info_regression

def train_and_interpret_mi(X, y, feature_names, task,
                            checkpoint_dir="./checkpoints",
                            selection_threshold=0.01,
                            random_seed=42):
    """
    用 Mutual Information 选特征（稀疏 mask）

    参数说明：
    - selection_threshold: MI 值阈值（越大越稀疏）
    """
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # 计算每个特征与目标的互信息
    mi_scores = mutual_info_regression(X_scaled, y, random_state=random_seed)

    # threshold 筛选
    selected_mask = mi_scores >= selection_threshold

    if np.sum(selected_mask) == 0:
        print("[Warning] No features passed MI threshold. Using all features.")
        selected_mask = np.ones_like(mi_scores, dtype=bool)

    # 没有拟合模型，MI 只是打分
    coef = mi_scores
    coef[~selected_mask] = 0

    selected_features = np.array(feature_names)[selected_mask]
    selected_importance = coef[selected_mask]

    # --- visualization ---
    plt.figure(figsize=(10, 4))
    plt.bar(np.arange(len(selected_importance)), selected_importance)
    plt.xticks(np.arange(len(selected_importance)), selected_features, rotation=90, fontsize=8)
    plt.title(f"Feature Importance (MI) for {task}")
    plt.tight_layout()
    plt.savefig(f"feature_importance_{task}_mi.png")
    plt.show()

    # --- save mask dict ---
    mask_dict = generate_mask_dict(feature_names, coef != 0)
    torch.save(mask_dict, f"parameter_mask_{task}_mi.pt")
    print(f"[Info] Saved parameter mask to parameter_mask_{task}_mi.pt")

    return selected_features, selected_importance


# --- Main ---
metric_table = pd.read_csv(METRIC_CSV)
all_tasks = [col for col in metric_table.columns if col.startswith("change_")]
task_features_list = {}

for task in all_tasks:
    X, y, feature_names = extract_features_and_labels(DATA_DIR, METRIC_CSV, task)
    selected_features, selected_importance = train_and_interpret_mi(X, y, feature_names, task)
    task_features_list[task] = (selected_features, selected_importance)

# %%
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.preprocessing import StandardScaler

def hsic(X, y, sigma=1.0):

    K = rbf_kernel(X, gamma=1 / (2 * sigma ** 2))
    y = y.reshape(-1, 1)
    L = rbf_kernel(y, gamma=1 / (2 * sigma ** 2))

    n = K.shape[0]
    H = np.eye(n) - 1 / n * np.ones((n, n))
    HKH = H @ K @ H
    HLH = H @ L @ H
    hsic_value = np.trace(HKH @ HLH) / (n - 1) ** 2
    return hsic_value

def train_and_interpret_hsic(X, y, feature_names, task,
                              checkpoint_dir="./checkpoints",
                              selection_threshold=0.01,
                              random_seed=42):

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    hsic_scores = []
    for i in range(X.shape[1]):
        score = hsic(X_scaled[:, i:i+1], y)
        hsic_scores.append(score)

    hsic_scores = np.array(hsic_scores)
    selected_mask = hsic_scores >= selection_threshold

    if np.sum(selected_mask) == 0:
        print("[Warning] No features passed HSIC threshold. Using all features.")
        selected_mask = np.ones_like(hsic_scores, dtype=bool)

    coef = hsic_scores
    coef[~selected_mask] = 0

    selected_features = np.array(feature_names)[selected_mask]
    selected_importance = coef[selected_mask]

    # --- visualization ---
    plt.figure(figsize=(10, 4))
    plt.bar(np.arange(len(selected_importance)), selected_importance)
    plt.xticks(np.arange(len(selected_importance)), selected_features, rotation=90, fontsize=8)
    plt.title(f"Feature Importance (HSIC) for {task}")
    plt.tight_layout()
    plt.savefig(f"feature_importance_{task}_hsic.png")
    plt.show()

    # --- save mask dict ---
    mask_dict = generate_mask_dict(feature_names, coef != 0)
    torch.save(mask_dict, f"parameter_mask_{task}_hsic.pt")
    print(f"[Info] Saved parameter mask to parameter_mask_{task}_hsic.pt")

    return selected_features, selected_importance


# --- Main ---
metric_table = pd.read_csv(METRIC_CSV)
all_tasks = [col for col in metric_table.columns if col.startswith("change_")]
task_features_list = {}

for task in all_tasks:
    X, y, feature_names = extract_features_and_labels(DATA_DIR, METRIC_CSV, task)
    selected_features, selected_importance = train_and_interpret_mi(X, y, feature_names, task)
    task_features_list[task] = (selected_features, selected_importance)

# %%
# selected_features, selected_importance = load_checkpoint_and_extract_features(task="task1")
# print("Selected Features:", selected_features)
# print("Importance:", selected_importance)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-6-2107283565.py in <cell line: 0>()
# ----> 1 selected_features, selected_importance = load_checkpoint_and_extract_features(task="task1")
#       2 print("Selected Features:", selected_features)
#       3 print("Importance:", selected_importance)
#
# /tmp/ipython-input-5-2546256116.py in load_checkpoint_and_extract_features(task, checkpoint_dir, plot)
#     198     features_path = os.path.join(checkpoint_dir, f"{task}_features.pkl")
#     199
# --> 200     scaler = joblib.load(scaler_path)
#     201     model = joblib.load(model_path)
#     202     feature_names = joblib.load(features_path)
#
# /usr/local/lib/python3.11/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode, ensure_native_byte_order)
#     733             obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734     else:
# --> 735         with open(filename, "rb") as f:
#     736             with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737                 fobj,
#
# FileNotFoundError: [Errno 2] No such file or directory: './checkpoints/task1_scaler.pkl'

# %% [markdown]
# ## Visualization

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import normalize
import pandas as pd
import numpy as np

all_features = sorted({feat for task_feats, _ in task_features_list.values() for feat in task_feats})

task_weight_vectors = {}
for task, (feats, imps) in task_features_list.items():
    weight_vec = np.zeros(len(all_features))
    for f, imp in zip(feats, imps):
        idx = all_features.index(f)
        weight_vec[idx] = imp
    task_weight_vectors[task] = weight_vec

def jaccard_similarity(a, b):
    return len(set(a) & set(b)) / len(set(a) | set(b))

jaccard_matrix = pd.DataFrame(index=task_features_list.keys(), columns=task_features_list.keys())
for task1 in task_features_list:
    for task2 in task_features_list:
        f1, _ = task_features_list[task1]
        f2, _ = task_features_list[task2]
        jaccard_matrix.loc[task1, task2] = jaccard_similarity(f1, f2)

print("Jaccard Similarity Matrix:")
print(jaccard_matrix.astype(float).round(3))


task_names = list(task_weight_vectors.keys())
weight_matrix = np.stack([task_weight_vectors[task] for task in task_names])
cosine_sim_matrix = cosine_similarity(weight_matrix)

cosine_matrix_df = pd.DataFrame(cosine_sim_matrix, index=task_names, columns=task_names)
print("\nCosine Similarity Matrix:")
print(cosine_matrix_df.round(3))
# Out:
# Jaccard Similarity Matrix:
#                    change_winogrande  change_gsm8k  change_mmlu  \
# change_winogrande              1.000         0.321        0.256
# change_gsm8k                   0.321         1.000        0.468
# change_mmlu                    0.256         0.468        1.000
# change_truthfulqa              0.383         0.477        0.345
# change_average                 0.140         0.114        0.122
#
#                    change_truthfulqa  change_average
# change_winogrande              0.383           0.140
# change_gsm8k                   0.477           0.114
# change_mmlu                    0.345           0.122
# change_truthfulqa              1.000           0.156
# change_average                 0.156           1.000
#
# Cosine Similarity Matrix:
#                    change_winogrande  change_gsm8k  change_mmlu  \
# change_winogrande              1.000         0.320        0.322
# change_gsm8k                   0.320         1.000        0.201
# change_mmlu                    0.322         0.201        1.000
# change_truthfulqa             -0.673        -0.509       -0.708
# change_average                 0.305         0.597        0.401
#
#                    change_truthfulqa  change_average
# change_winogrande             -0.673           0.305
# change_gsm8k                  -0.509           0.597
# change_mmlu                   -0.708           0.401
# change_truthfulqa              1.000          -0.407
# change_average                -0.407           1.000

# %%
# prompt: visualize two matrix and remove change_average

import matplotlib.pyplot as plt
import seaborn as sns

tasks_to_visualize = [task for task in task_names if task != "change_average"]

# Filter the cosine similarity matrix
cosine_matrix_filtered = cosine_matrix_df.loc[tasks_to_visualize, tasks_to_visualize]

# Visualize the Cosine Similarity Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cosine_matrix_filtered.astype(float), annot=True, fmt=".2f", cmap="viridis")
plt.title("Cosine Similarity Matrix")
plt.show()


# Filter the Jaccard similarity matrix
jaccard_matrix_filtered = jaccard_matrix.loc[tasks_to_visualize, tasks_to_visualize]

# Visualize the Jaccard Similarity Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(jaccard_matrix_filtered.astype(float), annot=True, fmt=".2f", cmap="viridis")
plt.title("Jaccard Similarity Matrix")
plt.show()

# %%
import torch
from typing import Dict, Optional
from transformers import AutoModelForCausalLM
import logging
import re

logger = logging.getLogger(__name__)

def generate_task_mask(
    task_name: str,
    task_features_list: Dict[str, tuple],
    base_model_path: str,
    save_path: Optional[str] = None,
) -> Dict[str, torch.Tensor]:
    """
    Generate a boolean mask for a specific task based on selected parameter names.
    Supports split keys like 'model.layers.3.mlp.down_proj.weight[0]'.

    Returns:
        Dict[str, torch.Tensor]: Dictionary of boolean masks.
    """
    if task_name not in task_features_list:
        raise ValueError(f"Task '{task_name}' not found in task_features_list.")

    logger.info(f"Loading base model weights from: {base_model_path}")
    state_dict = AutoModelForCausalLM.from_pretrained(base_model_path).state_dict()

    selected_features, _ = task_features_list[task_name]
    selected_features_set = set(selected_features)

    logger.info(f"Generating mask for task: {task_name} using {len(selected_features_set)} selected features.")
    mask_dict: Dict[str, torch.Tensor] = {}
    split_map: Dict[str, list] = {}

    for name in selected_features_set:
        if "[" in name and name.endswith("]"):
            base_key, idx = re.match(r"^(.*)\[(\d+)\]$", name).groups()
            idx = int(idx)
            split_map.setdefault(base_key, []).append(idx)
        else:
            split_map.setdefault(name, None)

    num_masked_keys = 0
    num_total_true = 0

    for key, tensor in state_dict.items():
        if not isinstance(tensor, torch.Tensor):
            continue

        if key not in split_map:
            mask = torch.zeros_like(tensor, dtype=torch.bool)
        elif split_map[key] is None:
            mask = torch.ones_like(tensor, dtype=torch.bool)
            num_masked_keys += 1
            num_total_true += mask.numel()
        else:
            split_indices = split_map[key]
            mask = torch.zeros_like(tensor, dtype=torch.bool)
            chunks = torch.chunk(tensor, max(split_indices) + 1, dim=0)
            split_sizes = [c.shape[0] for c in chunks]
            offsets = [0] + list(torch.cumsum(torch.tensor(split_sizes[:-1]), dim=0))
            for idx in split_indices:
                start = offsets[idx]
                end = start + split_sizes[idx]
                mask[start:end] = True
                num_total_true += (end - start)
            num_masked_keys += 1

        mask_dict[key] = mask

    print(f"Masked keys (with any True): {num_masked_keys} out of {len(state_dict)} parameters")
    print(f"Total masked parameters (True values): {num_total_true}")

    if save_path:
        torch.save(mask_dict, save_path)
        logger.info(f"Task mask saved to: {save_path}")

    return mask_dict

# %%
for task_name in task_names:
    mask = generate_task_mask(
    task_name=task_name,
    task_features_list=task_features_list,
    base_model_path="yedi-hu/slerp_llama_2_child-1-1-float16",
    save_path=f"{task_name}_mask"
  )
# Out:
# config.json:   0%|          | 0.00/698 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/183 [00:00<?, ?B/s]
# Masked keys (with any True): 150 out of 291 parameters
# Total masked parameters (True values): 416696
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Masked keys (with any True): 216 out of 291 parameters
# Total masked parameters (True values): 846906
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Masked keys (with any True): 233 out of 291 parameters
# Total masked parameters (True values): 853581
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Masked keys (with any True): 182 out of 291 parameters
# Total masked parameters (True values): 585031
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Masked keys (with any True): 82 out of 291 parameters
# Total masked parameters (True values): 200452

# %% [markdown]
# ## Manual Mask Gen

# %%
import torch
from scipy.stats import pearsonr

def flatten_dict_values(d):
    # Convert boolean tensors to float (True=1.0, False=0.0) and flatten
    return torch.cat([v.flatten().to(torch.float32) for v in d.values()])
dict1 = torch.load('mask_test')
dict2 = torch.load('truthfulqa_mask')

# Flatten all values
flat1 = flatten_dict_values(dict1)
flat2 = flatten_dict_values(dict2)

# Truncate to the shorter length
min_len = min(len(flat1), len(flat2))
flat1 = flat1[:min_len]
flat2 = flat2[:min_len]

# Compute Pearson correlation
correlation, _ = pearsonr(flat1.numpy(), flat2.numpy())
print("Correlation:", correlation)
# Out:
# Correlation: 0.15573627

# %%
# !generate_mask yedi-hu/Llama-2-7b-gsm8k-float16 \
yedi-hu/slerp_llama_2_child-1-6-float16 \
mask_test\
-p 0.5
# Out:
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.14s/it]
# Loading checkpoint shards: 100% 3/3 [00:03<00:00,  1.14s/it]
# Saving task mask to mask_test

# %% [markdown]
# ## Merge

# %%
# !slerp_merge \
yedi-hu/slerp_llama_2_child-2-6-float16 \
yedi-hu/Llama-2-7b-truthfulqa-float16 \
./slerp_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7\
-m change_truthfulqa_mask
# Out:
# config.json: 100% 698/698 [00:00<00:00, 5.58MB/s]
# model.safetensors.index.json: 24.0kB [00:00, 84.5MB/s]
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.94G [00:00<?, ?B/s]
#
# model-00002-of-00003.safetensors:   0% 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.94G [00:00<00:52, 94.5MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 0.00/3.59G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.94G [00:00<00:31, 158MB/s]
#
# model-00002-of-00003.safetensors:   0% 10.5M/4.95G [00:00<01:16, 64.6MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 10.5M/3.59G [00:00<00:55, 64.4MB/s]
# model-00001-of-00003.safetensors:   1% 62.9M/4.94G [00:00<00:24, 201MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 21.0M/3.59G [00:00<00:48, 73.1MB/s]
#
# model-00002-of-00003.safetensors:   1% 31.5M/4.95G [00:00<00:55, 88.0MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.94G [00:00<00:21, 224MB/s]
# model-00001-of-00003.safetensors:   3% 126M/4.94G [00:00<00:19, 245MB/s]
#
# model-00002-of-00003.safetensors:   1% 41.9M/4.95G [00:00<00:56, 86.3MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 31.5M/3.59G [00:00<00:51, 69.1MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.94G [00:00<00:18, 256MB/s]
#
# model-00002-of-00003.safetensors:   1% 52.4M/4.95G [00:00<00:56, 86.7MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 41.9M/3.59G [00:00<00:47, 74.0MB/s]
# model-00001-of-00003.safetensors:   4% 189M/4.94G [00:00<00:18, 261MB/s]
#
# model-00002-of-00003.safetensors:   1% 62.9M/4.95G [00:00<00:58, 83.1MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 52.4M/3.59G [00:00<00:46, 76.8MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.94G [00:00<00:17, 268MB/s]
#
# model-00002-of-00003.safetensors:   1% 73.4M/4.95G [00:00<00:56, 86.7MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 62.9M/3.59G [00:00<00:44, 78.5MB/s]
# model-00001-of-00003.safetensors:   5% 252M/4.94G [00:01<00:17, 262MB/s]
#
# model-00002-of-00003.safetensors:   2% 83.9M/4.95G [00:00<00:56, 86.8MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 73.4M/3.59G [00:00<00:44, 79.9MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.94G [00:01<00:17, 268MB/s]
#
# model-00002-of-00003.safetensors:   2% 94.4M/4.95G [00:01<00:56, 85.2MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 83.9M/3.59G [00:01<00:43, 81.5MB/s]
# model-00001-of-00003.safetensors:   6% 315M/4.94G [00:01<00:16, 275MB/s]
#
# model-00002-of-00003.safetensors:   2% 105M/4.95G [00:01<00:56, 86.0MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 94.4M/3.59G [00:01<00:43, 80.6MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.94G [00:01<00:16, 276MB/s]
#
# model-00002-of-00003.safetensors:   2% 115M/4.95G [00:01<00:56, 84.8MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 105M/3.59G [00:01<00:43, 81.0MB/s]
# model-00001-of-00003.safetensors:   8% 377M/4.94G [00:01<00:16, 280MB/s]
#
# model-00002-of-00003.safetensors:   3% 126M/4.95G [00:01<00:56, 85.4MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.94G [00:01<00:16, 280MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 115M/3.59G [00:01<00:42, 81.6MB/s]
#
# model-00002-of-00003.safetensors:   3% 136M/4.95G [00:01<00:56, 85.7MB/s]
# model-00001-of-00003.safetensors:   9% 440M/4.94G [00:01<00:16, 279MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 126M/3.59G [00:01<00:42, 82.0MB/s]
#
# model-00002-of-00003.safetensors:   3% 147M/4.95G [00:01<00:55, 86.6MB/s]
# model-00001-of-00003.safetensors:  10% 472M/4.94G [00:01<00:16, 274MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 136M/3.59G [00:01<00:41, 82.3MB/s]
#
# model-00002-of-00003.safetensors:   3% 157M/4.95G [00:01<00:55, 86.2MB/s]
# model-00001-of-00003.safetensors:  10% 503M/4.94G [00:01<00:15, 278MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 147M/3.59G [00:01<00:41, 82.4MB/s]
#
# model-00002-of-00003.safetensors:   3% 168M/4.95G [00:01<00:55, 86.2MB/s]
# model-00001-of-00003.safetensors:  11% 535M/4.94G [00:02<00:15, 278MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 157M/3.59G [00:01<00:41, 82.6MB/s]
# model-00001-of-00003.safetensors:  11% 566M/4.94G [00:02<00:15, 279MB/s]
#
# model-00002-of-00003.safetensors:   4% 178M/4.95G [00:02<00:55, 85.9MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 168M/3.59G [00:02<00:41, 82.6MB/s]
# model-00001-of-00003.safetensors:  12% 598M/4.94G [00:02<00:15, 280MB/s]
#
# model-00002-of-00003.safetensors:   4% 189M/4.95G [00:02<00:55, 85.8MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 178M/3.59G [00:02<00:41, 82.7MB/s]
# model-00001-of-00003.safetensors:  13% 629M/4.94G [00:02<00:15, 276MB/s]
#
# model-00002-of-00003.safetensors:   4% 199M/4.95G [00:02<00:55, 85.7MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 189M/3.59G [00:02<00:41, 82.8MB/s]
# model-00001-of-00003.safetensors:  13% 661M/4.94G [00:02<00:15, 279MB/s]
#
# model-00002-of-00003.safetensors:   4% 210M/4.95G [00:02<00:56, 83.3MB/s]
# model-00001-of-00003.safetensors:  14% 692M/4.94G [00:02<00:15, 278MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 199M/3.59G [00:02<00:41, 82.4MB/s]
#
# model-00002-of-00003.safetensors:   4% 220M/4.95G [00:02<00:54, 86.0MB/s]
# model-00001-of-00003.safetensors:  15% 724M/4.94G [00:02<00:15, 280MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 210M/3.59G [00:02<00:40, 82.8MB/s]
#
# model-00002-of-00003.safetensors:   5% 231M/4.95G [00:02<00:55, 85.7MB/s]
# model-00001-of-00003.safetensors:  15% 755M/4.94G [00:02<00:14, 280MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 220M/3.59G [00:02<00:40, 82.7MB/s]
#
# model-00002-of-00003.safetensors:   5% 241M/4.95G [00:02<00:55, 84.5MB/s]
# model-00001-of-00003.safetensors:  16% 786M/4.94G [00:02<00:14, 279MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 231M/3.59G [00:02<00:40, 82.8MB/s]
#
# model-00002-of-00003.safetensors:   5% 252M/4.95G [00:02<00:54, 86.3MB/s]
# model-00001-of-00003.safetensors:  17% 818M/4.94G [00:03<00:15, 271MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 241M/3.59G [00:02<00:40, 82.8MB/s]
#
# model-00002-of-00003.safetensors:   5% 262M/4.95G [00:03<00:54, 85.3MB/s]
# model-00001-of-00003.safetensors:  17% 849M/4.94G [00:03<00:15, 270MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 252M/3.59G [00:03<00:40, 81.9MB/s]
#
# model-00002-of-00003.safetensors:   6% 273M/4.95G [00:03<00:54, 86.4MB/s]
# model-00001-of-00003.safetensors:  18% 881M/4.94G [00:03<00:14, 273MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 262M/3.59G [00:03<00:40, 83.1MB/s]
#
# model-00002-of-00003.safetensors:   6% 283M/4.95G [00:03<00:54, 85.3MB/s]
# model-00001-of-00003.safetensors:  18% 912M/4.94G [00:03<00:14, 273MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 273M/3.59G [00:03<00:40, 82.5MB/s]
#
# model-00002-of-00003.safetensors:   6% 294M/4.95G [00:03<00:54, 85.2MB/s]
# model-00001-of-00003.safetensors:  19% 944M/4.94G [00:03<00:14, 272MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 283M/3.59G [00:03<00:39, 82.8MB/s]
#
# model-00002-of-00003.safetensors:   6% 304M/4.95G [00:03<00:54, 85.7MB/s]
# model-00001-of-00003.safetensors:  20% 975M/4.94G [00:03<00:14, 274MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 294M/3.59G [00:03<00:39, 83.0MB/s]
#
# model-00002-of-00003.safetensors:   6% 315M/4.95G [00:03<00:53, 85.9MB/s]
# model-00001-of-00003.safetensors:  20% 1.01G/4.94G [00:03<00:14, 274MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 304M/3.59G [00:03<00:39, 83.3MB/s]
# model-00001-of-00003.safetensors:  21% 1.04G/4.94G [00:03<00:14, 270MB/s]
#
# model-00002-of-00003.safetensors:   7% 325M/4.95G [00:03<00:54, 85.2MB/s]
# model-00001-of-00003.safetensors:  22% 1.07G/4.94G [00:03<00:14, 272MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 315M/3.59G [00:03<00:39, 83.0MB/s]
#
# model-00002-of-00003.safetensors:   7% 336M/4.95G [00:03<00:54, 85.0MB/s]
# model-00001-of-00003.safetensors:  22% 1.10G/4.94G [00:04<00:14, 274MB/s]
#
# model-00002-of-00003.safetensors:   7% 346M/4.95G [00:04<00:54, 85.1MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 325M/3.59G [00:04<00:39, 82.6MB/s]
# model-00001-of-00003.safetensors:  23% 1.13G/4.94G [00:04<00:14, 265MB/s]
#
# model-00002-of-00003.safetensors:   7% 357M/4.95G [00:04<00:53, 86.0MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 336M/3.59G [00:04<00:39, 83.1MB/s]
# model-00001-of-00003.safetensors:  24% 1.16G/4.94G [00:04<00:14, 269MB/s]
#
# model-00002-of-00003.safetensors:   7% 367M/4.95G [00:04<00:53, 85.6MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 346M/3.59G [00:04<00:39, 82.9MB/s]
# model-00001-of-00003.safetensors:  24% 1.20G/4.94G [00:04<00:13, 269MB/s]
#
# model-00002-of-00003.safetensors:   8% 377M/4.95G [00:04<00:53, 85.6MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 357M/3.59G [00:04<00:39, 82.6MB/s]
# model-00001-of-00003.safetensors:  25% 1.23G/4.94G [00:04<00:13, 272MB/s]
#
# model-00002-of-00003.safetensors:   8% 388M/4.95G [00:04<00:53, 85.4MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 367M/3.59G [00:04<00:39, 81.6MB/s]
# model-00001-of-00003.safetensors:  25% 1.26G/4.94G [00:04<00:13, 269MB/s]
#
# model-00002-of-00003.safetensors:   8% 398M/4.95G [00:04<00:53, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 377M/3.59G [00:04<00:39, 81.1MB/s]
# model-00001-of-00003.safetensors:  26% 1.29G/4.94G [00:04<00:13, 270MB/s]
#
# model-00002-of-00003.safetensors:   8% 409M/4.95G [00:04<00:53, 85.2MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 388M/3.59G [00:04<00:38, 83.5MB/s]
# model-00001-of-00003.safetensors:  27% 1.32G/4.94G [00:04<00:13, 273MB/s]
#
# model-00002-of-00003.safetensors:   8% 419M/4.95G [00:04<00:53, 84.0MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 398M/3.59G [00:04<00:38, 82.8MB/s]
# model-00001-of-00003.safetensors:  27% 1.35G/4.94G [00:05<00:13, 276MB/s]
#
# model-00002-of-00003.safetensors:   9% 430M/4.95G [00:05<00:56, 80.5MB/s]
# model-00001-of-00003.safetensors:  28% 1.38G/4.94G [00:05<00:12, 278MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 409M/3.59G [00:05<00:40, 79.4MB/s]
# model-00001-of-00003.safetensors:  29% 1.42G/4.94G [00:05<00:12, 280MB/s]
#
# model-00002-of-00003.safetensors:   9% 440M/4.95G [00:05<00:55, 81.8MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 419M/3.59G [00:05<00:39, 79.5MB/s]
#
# model-00002-of-00003.safetensors:   9% 451M/4.95G [00:05<00:54, 83.0MB/s]
# model-00001-of-00003.safetensors:  29% 1.45G/4.94G [00:05<00:12, 270MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 430M/3.59G [00:05<00:39, 80.2MB/s]
# model-00001-of-00003.safetensors:  30% 1.48G/4.94G [00:05<00:12, 271MB/s]
#
# model-00002-of-00003.safetensors:   9% 461M/4.95G [00:05<00:53, 83.5MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 440M/3.59G [00:05<00:38, 80.9MB/s]
# model-00001-of-00003.safetensors:  31% 1.51G/4.94G [00:05<00:12, 273MB/s]
#
# model-00002-of-00003.safetensors:  10% 472M/4.95G [00:05<00:53, 84.0MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 451M/3.59G [00:05<00:38, 81.4MB/s]
# model-00001-of-00003.safetensors:  31% 1.54G/4.94G [00:05<00:12, 276MB/s]
#
# model-00002-of-00003.safetensors:  10% 482M/4.95G [00:05<00:53, 83.8MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 461M/3.59G [00:05<00:38, 81.6MB/s]
# model-00001-of-00003.safetensors:  32% 1.57G/4.94G [00:05<00:12, 275MB/s]
#
# model-00002-of-00003.safetensors:  10% 493M/4.95G [00:05<00:53, 83.9MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 472M/3.59G [00:05<00:38, 81.7MB/s]
# model-00001-of-00003.safetensors:  32% 1.60G/4.94G [00:05<00:12, 273MB/s]
#
# model-00002-of-00003.safetensors:  10% 503M/4.95G [00:05<00:53, 83.8MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 482M/3.59G [00:05<00:37, 81.9MB/s]
# model-00001-of-00003.safetensors:  33% 1.64G/4.94G [00:06<00:11, 276MB/s]
#
# model-00002-of-00003.safetensors:  10% 514M/4.95G [00:06<00:52, 84.2MB/s]
# model-00001-of-00003.safetensors:  34% 1.67G/4.94G [00:06<00:11, 275MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 493M/3.59G [00:06<00:37, 82.0MB/s]
#
# model-00002-of-00003.safetensors:  11% 524M/4.95G [00:06<00:52, 84.4MB/s]
# model-00001-of-00003.safetensors:  34% 1.70G/4.94G [00:06<00:11, 277MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 503M/3.59G [00:06<00:37, 82.4MB/s]
#
# model-00002-of-00003.safetensors:  11% 535M/4.95G [00:06<00:52, 84.6MB/s]
# model-00001-of-00003.safetensors:  35% 1.73G/4.94G [00:06<00:11, 278MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 514M/3.59G [00:06<00:38, 80.2MB/s]
#
# model-00002-of-00003.safetensors:  11% 545M/4.95G [00:06<00:51, 84.7MB/s]
# model-00001-of-00003.safetensors:  36% 1.76G/4.94G [00:06<00:11, 278MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 524M/3.59G [00:06<00:36, 83.0MB/s]
#
# model-00002-of-00003.safetensors:  11% 556M/4.95G [00:06<00:51, 84.9MB/s]
# model-00001-of-00003.safetensors:  36% 1.79G/4.94G [00:06<00:11, 280MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 535M/3.59G [00:06<00:36, 82.8MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.94G [00:06<00:11, 281MB/s]
#
# model-00002-of-00003.safetensors:  11% 566M/4.95G [00:06<00:51, 85.1MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 545M/3.59G [00:06<00:36, 82.5MB/s]
# model-00001-of-00003.safetensors:  38% 1.86G/4.94G [00:06<00:11, 280MB/s]
#
# model-00002-of-00003.safetensors:  12% 577M/4.95G [00:06<00:51, 85.1MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 556M/3.59G [00:06<00:36, 82.4MB/s]
# model-00001-of-00003.safetensors:  38% 1.89G/4.94G [00:06<00:11, 277MB/s]
#
# model-00002-of-00003.safetensors:  12% 587M/4.95G [00:06<00:51, 85.2MB/s]
# model-00001-of-00003.safetensors:  39% 1.92G/4.94G [00:07<00:10, 279MB/s]
#
#
# model-00003-of-00003.safetensors:  16% 566M/3.59G [00:06<00:36, 82.2MB/s]
#
# model-00002-of-00003.safetensors:  12% 598M/4.95G [00:07<00:51, 85.0MB/s]
# model-00001-of-00003.safetensors:  39% 1.95G/4.94G [00:07<00:10, 274MB/s]
#
#
# model-00003-of-00003.safetensors:  16% 577M/3.59G [00:07<00:36, 82.5MB/s]
#
# model-00002-of-00003.safetensors:  12% 608M/4.95G [00:07<00:50, 85.1MB/s]
# model-00001-of-00003.safetensors:  40% 1.98G/4.94G [00:07<00:10, 273MB/s]
#
#
# model-00003-of-00003.safetensors:  16% 587M/3.59G [00:07<00:36, 82.1MB/s]
#
# model-00002-of-00003.safetensors:  13% 619M/4.95G [00:07<00:50, 85.3MB/s]
# model-00001-of-00003.safetensors:  41% 2.01G/4.94G [00:07<00:10, 274MB/s]
#
#
# model-00003-of-00003.safetensors:  17% 598M/3.59G [00:07<00:36, 81.5MB/s]
#
# model-00002-of-00003.safetensors:  13% 629M/4.95G [00:07<00:50, 85.4MB/s]
# model-00001-of-00003.safetensors:  41% 2.04G/4.94G [00:07<00:10, 272MB/s]
#
#
# model-00003-of-00003.safetensors:  17% 608M/3.59G [00:07<00:36, 82.1MB/s]
#
# model-00002-of-00003.safetensors:  13% 640M/4.95G [00:07<00:50, 85.5MB/s]
# model-00001-of-00003.safetensors:  42% 2.08G/4.94G [00:07<00:10, 266MB/s]
#
#
# model-00003-of-00003.safetensors:  17% 619M/3.59G [00:07<00:36, 82.5MB/s]
#
# model-00002-of-00003.safetensors:  13% 650M/4.95G [00:07<00:50, 85.4MB/s]
# model-00001-of-00003.safetensors:  43% 2.11G/4.94G [00:07<00:10, 260MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 629M/3.59G [00:07<00:35, 82.6MB/s]
#
# model-00002-of-00003.safetensors:  13% 661M/4.95G [00:07<00:50, 85.4MB/s]
# model-00001-of-00003.safetensors:  43% 2.14G/4.94G [00:07<00:10, 262MB/s]
#
# model-00002-of-00003.safetensors:  14% 671M/4.95G [00:07<00:50, 85.2MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 640M/3.59G [00:07<00:35, 82.2MB/s]
# model-00001-of-00003.safetensors:  44% 2.17G/4.94G [00:08<00:10, 261MB/s]
#
# model-00002-of-00003.safetensors:  14% 682M/4.95G [00:08<00:49, 85.7MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 650M/3.59G [00:07<00:35, 82.0MB/s]
# model-00001-of-00003.safetensors:  45% 2.20G/4.94G [00:08<00:10, 266MB/s]
#
# model-00002-of-00003.safetensors:  14% 692M/4.95G [00:08<00:50, 85.0MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 661M/3.59G [00:08<00:35, 82.4MB/s]
# model-00001-of-00003.safetensors:  45% 2.23G/4.94G [00:08<00:10, 265MB/s]
#
# model-00002-of-00003.safetensors:  14% 703M/4.95G [00:08<00:49, 85.8MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 671M/3.59G [00:08<00:35, 83.1MB/s]
# model-00001-of-00003.safetensors:  46% 2.26G/4.94G [00:08<00:10, 261MB/s]
#
# model-00002-of-00003.safetensors:  14% 713M/4.95G [00:08<00:49, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 682M/3.59G [00:08<00:35, 82.7MB/s]
# model-00001-of-00003.safetensors:  46% 2.30G/4.94G [00:08<00:10, 258MB/s]
#
# model-00002-of-00003.safetensors:  15% 724M/4.95G [00:08<00:49, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 692M/3.59G [00:08<00:35, 82.7MB/s]
# model-00001-of-00003.safetensors:  47% 2.33G/4.94G [00:08<00:10, 259MB/s]
#
# model-00002-of-00003.safetensors:  15% 734M/4.95G [00:08<00:49, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  20% 703M/3.59G [00:08<00:34, 82.7MB/s]
# model-00001-of-00003.safetensors:  48% 2.36G/4.94G [00:08<00:09, 258MB/s]
#
# model-00002-of-00003.safetensors:  15% 744M/4.95G [00:08<00:49, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:  20% 713M/3.59G [00:08<00:34, 83.1MB/s]
# model-00001-of-00003.safetensors:  48% 2.39G/4.94G [00:08<00:09, 259MB/s]
#
# model-00002-of-00003.safetensors:  15% 755M/4.95G [00:08<00:48, 85.7MB/s]
#
#
# model-00003-of-00003.safetensors:  20% 724M/3.59G [00:08<00:34, 83.0MB/s]
# model-00001-of-00003.safetensors:  49% 2.42G/4.94G [00:09<00:09, 265MB/s]
#
# model-00002-of-00003.safetensors:  15% 765M/4.95G [00:08<00:48, 85.7MB/s]
# model-00001-of-00003.safetensors:  50% 2.45G/4.94G [00:09<00:09, 270MB/s]
#
#
# model-00003-of-00003.safetensors:  20% 734M/3.59G [00:08<00:34, 82.8MB/s]
#
# model-00002-of-00003.safetensors:  16% 776M/4.95G [00:09<00:48, 85.2MB/s]
# model-00001-of-00003.safetensors:  50% 2.49G/4.94G [00:09<00:09, 269MB/s]
#
#
# model-00003-of-00003.safetensors:  21% 744M/3.59G [00:09<00:34, 83.1MB/s]
#
# model-00002-of-00003.safetensors:  16% 786M/4.95G [00:09<00:48, 85.7MB/s]
# model-00001-of-00003.safetensors:  51% 2.52G/4.94G [00:09<00:08, 274MB/s]
#
#
# model-00003-of-00003.safetensors:  21% 755M/3.59G [00:09<00:34, 82.8MB/s]
#
# model-00002-of-00003.safetensors:  16% 797M/4.95G [00:09<00:48, 85.6MB/s]
# model-00001-of-00003.safetensors:  52% 2.55G/4.94G [00:09<00:08, 278MB/s]
# model-00001-of-00003.safetensors:  52% 2.58G/4.94G [00:09<00:08, 279MB/s]
#
# model-00002-of-00003.safetensors:  16% 807M/4.95G [00:09<00:48, 84.7MB/s]
#
#
# model-00003-of-00003.safetensors:  21% 765M/3.59G [00:09<00:42, 67.0MB/s]
# model-00001-of-00003.safetensors:  53% 2.61G/4.94G [00:09<00:08, 279MB/s]
#
# model-00002-of-00003.safetensors:  17% 818M/4.95G [00:09<00:48, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 776M/3.59G [00:09<00:38, 72.3MB/s]
# model-00001-of-00003.safetensors:  54% 2.64G/4.94G [00:09<00:08, 279MB/s]
#
# model-00002-of-00003.safetensors:  17% 828M/4.95G [00:09<00:48, 85.7MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 786M/3.59G [00:09<00:42, 66.3MB/s]
# model-00001-of-00003.safetensors:  54% 2.67G/4.94G [00:09<00:08, 274MB/s]
#
# model-00002-of-00003.safetensors:  17% 839M/4.95G [00:09<00:48, 85.3MB/s]
# model-00001-of-00003.safetensors:  55% 2.71G/4.94G [00:10<00:08, 271MB/s]
#
# model-00002-of-00003.safetensors:  17% 849M/4.95G [00:09<00:48, 83.9MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 797M/3.59G [00:09<00:44, 62.6MB/s]
#
# model-00002-of-00003.safetensors:  17% 860M/4.95G [00:10<00:51, 79.8MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 807M/3.59G [00:10<00:45, 61.2MB/s]
#
# model-00002-of-00003.safetensors:  18% 870M/4.95G [00:10<00:56, 72.2MB/s]
# model-00001-of-00003.safetensors:  55% 2.74G/4.94G [00:10<00:13, 159MB/s]
#
#
# model-00003-of-00003.safetensors:  23% 818M/3.59G [00:10<00:44, 62.8MB/s]
# model-00001-of-00003.safetensors:  56% 2.77G/4.94G [00:10<00:11, 181MB/s]
#
# model-00002-of-00003.safetensors:  18% 891M/4.95G [00:10<00:46, 87.9MB/s]
# model-00001-of-00003.safetensors:  57% 2.80G/4.94G [00:10<00:10, 198MB/s]
#
#
# model-00003-of-00003.safetensors:  23% 828M/3.59G [00:10<00:49, 55.7MB/s]
#
# model-00002-of-00003.safetensors:  18% 902M/4.95G [00:10<00:49, 81.6MB/s]
# model-00001-of-00003.safetensors:  57% 2.83G/4.94G [00:10<00:10, 193MB/s]
#
#
# model-00003-of-00003.safetensors:  23% 839M/3.59G [00:10<00:50, 54.8MB/s]
#
# model-00002-of-00003.safetensors:  19% 923M/4.95G [00:10<00:45, 87.8MB/s]
# model-00001-of-00003.safetensors:  58% 2.86G/4.94G [00:11<00:12, 172MB/s]
#
# model-00002-of-00003.safetensors:  19% 933M/4.95G [00:10<00:45, 87.3MB/s]
#
#
# model-00003-of-00003.safetensors:  24% 860M/3.59G [00:11<00:45, 60.6MB/s]
#
# model-00002-of-00003.safetensors:  19% 944M/4.95G [00:11<00:46, 86.6MB/s]
# model-00001-of-00003.safetensors:  59% 2.89G/4.94G [00:11<00:11, 179MB/s]
#
#
# model-00003-of-00003.safetensors:  24% 870M/3.59G [00:11<00:42, 64.8MB/s]
#
# model-00002-of-00003.safetensors:  19% 954M/4.95G [00:11<00:46, 86.0MB/s]
# model-00001-of-00003.safetensors:  59% 2.93G/4.94G [00:11<00:10, 192MB/s]
#
# model-00002-of-00003.safetensors:  19% 965M/4.95G [00:11<00:46, 85.7MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 881M/3.59G [00:11<00:43, 62.7MB/s]
# model-00001-of-00003.safetensors:  60% 2.95G/4.94G [00:11<00:12, 165MB/s]
#
# model-00002-of-00003.safetensors:  20% 975M/4.95G [00:11<00:49, 80.1MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 891M/3.59G [00:11<00:46, 58.5MB/s]
#
# model-00002-of-00003.safetensors:  20% 996M/4.95G [00:11<00:45, 86.2MB/s]
# model-00001-of-00003.safetensors:  60% 2.97G/4.94G [00:11<00:16, 122MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 902M/3.59G [00:11<00:48, 55.9MB/s]
#
# model-00002-of-00003.safetensors:  20% 1.01G/4.95G [00:11<00:45, 86.0MB/s]
# model-00001-of-00003.safetensors:  61% 2.99G/4.94G [00:11<00:15, 129MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 912M/3.59G [00:11<00:47, 56.9MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.02G/4.95G [00:12<00:49, 79.4MB/s]
# model-00001-of-00003.safetensors:  61% 3.01G/4.94G [00:12<00:13, 138MB/s]
#
#
# model-00003-of-00003.safetensors:  26% 923M/3.59G [00:12<00:41, 65.1MB/s]
# model-00001-of-00003.safetensors:  62% 3.04G/4.94G [00:12<00:12, 151MB/s]
#
#
# model-00003-of-00003.safetensors:  26% 933M/3.59G [00:12<00:37, 70.2MB/s]
#
# model-00002-of-00003.safetensors:  21% 1
B/s]
#
# model-00002-of-00003.safetensors:  29% 1.42G/4.95G [00:16<00:41, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  34% 1.24G/3.59G [00:16<00:33, 70.4MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.43G/4.95G [00:16<00:41, 85.0MB/s]
# model-00001-of-00003.safetensors:  73% 3.61G/4.94G [00:16<00:11, 119MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.25G/3.59G [00:16<00:34, 67.0MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.44G/4.95G [00:16<00:41, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.26G/3.59G [00:16<00:33, 69.8MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.45G/4.95G [00:17<00:41, 84.9MB/s]
# model-00001-of-00003.safetensors:  73% 3.63G/4.94G [00:17<00:12, 107MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.27G/3.59G [00:17<00:32, 72.3MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.46G/4.95G [00:17<00:41, 84.7MB/s]
# model-00001-of-00003.safetensors:  74% 3.65G/4.94G [00:17<00:11, 114MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.47G/4.95G [00:17<00:41, 84.8MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.28G/3.59G [00:17<00:34, 67.9MB/s]
# model-00001-of-00003.safetensors:  74% 3.67G/4.94G [00:17<00:11, 112MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.48G/4.95G [00:17<00:41, 84.4MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.29G/3.59G [00:17<00:32, 70.4MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.49G/4.95G [00:17<00:40, 84.7MB/s]
# model-00001-of-00003.safetensors:  75% 3.69G/4.94G [00:17<00:10, 118MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.30G/3.59G [00:17<00:34, 67.2MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.50G/4.95G [00:17<00:40, 84.8MB/s]
# model-00001-of-00003.safetensors:  75% 3.71G/4.94G [00:17<00:09, 129MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.31G/3.59G [00:17<00:32, 69.5MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.51G/4.95G [00:17<00:40, 84.7MB/s]
# model-00001-of-00003.safetensors:  76% 3.73G/4.94G [00:17<00:09, 134MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.52G/4.95G [00:17<00:40, 84.7MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.32G/3.59G [00:17<00:31, 71.9MB/s]
# model-00001-of-00003.safetensors:  76% 3.76G/4.94G [00:18<00:07, 163MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.53G/4.95G [00:18<00:40, 84.8MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.33G/3.59G [00:18<00:33, 67.9MB/s]
# model-00001-of-00003.safetensors:  77% 3.80G/4.94G [00:18<00:06, 185MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.54G/4.95G [00:18<00:40, 84.8MB/s]
# model-00001-of-00003.safetensors:  77% 3.83G/4.94G [00:18<00:05, 201MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.34G/3.59G [00:18<00:31, 70.5MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.55G/4.95G [00:18<00:40, 84.6MB/s]
# model-00001-of-00003.safetensors:  78% 3.86G/4.94G [00:18<00:05, 212MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.35G/3.59G [00:18<00:33, 67.7MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.56G/4.95G [00:18<00:40, 84.0MB/s]
# model-00001-of-00003.safetensors:  79% 3.89G/4.94G [00:18<00:04, 224MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.57G/4.95G [00:18<00:39, 84.6MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.36G/3.59G [00:18<00:32, 69.4MB/s]
# model-00001-of-00003.safetensors:  79% 3.92G/4.94G [00:18<00:04, 230MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.58G/4.95G [00:18<00:39, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.37G/3.59G [00:18<00:30, 71.9MB/s]
# model-00001-of-00003.safetensors:  80% 3.95G/4.94G [00:18<00:04, 233MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.59G/4.95G [00:18<00:39, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.38G/3.59G [00:18<00:32, 67.9MB/s]
# model-00001-of-00003.safetensors:  81% 3.98G/4.94G [00:18<00:04, 229MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.60G/4.95G [00:18<00:39, 85.0MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.39G/3.59G [00:18<00:31, 70.6MB/s]
# model-00001-of-00003.safetensors:  81% 4.02G/4.94G [00:19<00:03, 238MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.61G/4.95G [00:19<00:39, 85.1MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.41G/3.59G [00:19<00:30, 72.3MB/s]
# model-00001-of-00003.safetensors:  82% 4.05G/4.94G [00:19<00:03, 246MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.63G/4.95G [00:19<00:39, 85.1MB/s]
# model-00001-of-00003.safetensors:  83% 4.08G/4.94G [00:19<00:03, 247MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.64G/4.95G [00:19<00:38, 85.2MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.42G/3.59G [00:19<00:31, 68.5MB/s]
# model-00001-of-00003.safetensors:  83% 4.11G/4.94G [00:19<00:03, 242MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.65G/4.95G [00:19<00:38, 85.3MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.43G/3.59G [00:19<00:30, 71.2MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.66G/4.95G [00:19<00:38, 85.1MB/s]
# model-00001-of-00003.safetensors:  84% 4.14G/4.94G [00:19<00:03, 237MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.44G/3.59G [00:19<00:31, 68.1MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.67G/4.95G [00:19<00:38, 85.0MB/s]
# model-00001-of-00003.safetensors:  84% 4.17G/4.94G [00:19<00:03, 239MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.45G/3.59G [00:19<00:30, 69.8MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.68G/4.95G [00:19<00:38, 84.2MB/s]
# model-00001-of-00003.safetensors:  85% 4.20G/4.94G [00:19<00:03, 222MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.46G/3.59G [00:19<00:29, 72.2MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.69G/4.95G [00:19<00:38, 84.2MB/s]
# model-00001-of-00003.safetensors:  86% 4.24G/4.94G [00:20<00:03, 221MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.70G/4.95G [00:20<00:38, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.47G/3.59G [00:19<00:31, 68.2MB/s]
# model-00001-of-00003.safetensors:  86% 4.27G/4.94G [00:20<00:02, 226MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.71G/4.95G [00:20<00:38, 84.9MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.48G/3.59G [00:20<00:29, 70.7MB/s]
# model-00001-of-00003.safetensors:  87% 4.30G/4.94G [00:20<00:02, 234MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.72G/4.95G [00:20<00:38, 84.6MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.49G/3.59G [00:20<00:28, 72.5MB/s]
# model-00001-of-00003.safetensors:  88% 4.33G/4.94G [00:20<00:02, 241MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.73G/4.95G [00:20<00:37, 84.8MB/s]
# model-00001-of-00003.safetensors:  88% 4.36G/4.94G [00:20<00:02, 248MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 1.50G/3.59G [00:20<00:30, 68.6MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.74G/4.95G [00:20<00:37, 84.9MB/s]
# model-00001-of-00003.safetensors:  89% 4.39G/4.94G [00:20<00:02, 256MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 1.51G/3.59G [00:20<00:29, 71.3MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.75G/4.95G [00:20<00:37, 85.1MB/s]
# model-00001-of-00003.safetensors:  90% 4.42G/4.94G [00:20<00:02, 256MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.76G/4.95G [00:20<00:37, 84.9MB/s]
# model-00001-of-00003.safetensors:  90% 4.46G/4.94G [00:20<00:01, 255MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 1.52G/3.59G [00:20<00:40, 51.1MB/s]
#
# model-00002-of-00003.safetensors:  36% 1
#
# model-00002-of-00003.safetensors:  52% 2.59G/4.95G [02:39<02:37, 14.9MB/s]
#
#
# model-00003-of-00003.safetensors:  67% 2.41G/3.59G [02:39<01:13, 16.1MB/s]
#
#
# model-00003-of-00003.safetensors:  67% 2.42G/3.59G [02:42<02:05, 9.33MB/s]
#
#
# model-00003-of-00003.safetensors:  68% 2.45G/3.59G [02:42<01:06, 17.1MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.60G/4.95G [02:42<04:35, 8.53MB/s]
#
#
# model-00003-of-00003.safetensors:  69% 2.49G/3.59G [02:42<00:40, 27.2MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.62G/4.95G [02:43<03:18, 11.7MB/s]
#
#
# model-00003-of-00003.safetensors:  70% 2.51G/3.59G [02:43<00:50, 21.4MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.63G/4.95G [02:43<03:16, 11.8MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.64G/4.95G [02:45<03:24, 11.3MB/s]
#
#
# model-00003-of-00003.safetensors:  70% 2.53G/3.59G [02:46<01:09, 15.4MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.65G/4.95G [02:46<03:42, 10.3MB/s]
#
#
# model-00003-of-00003.safetensors:  71% 2.55G/3.59G [02:46<00:52, 19.9MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.67G/4.95G [02:49<04:14, 8.94MB/s]
#
#
# model-00003-of-00003.safetensors:  71% 2.56G/3.59G [02:49<01:25, 12.1MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.71G/4.95G [02:49<02:16, 16.4MB/s]
#
#
# model-00003-of-00003.safetensors:  72% 2.59G/3.59G [02:49<00:52, 19.2MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.72G/4.95G [02:49<02:16, 16.4MB/s]
#
#
# model-00003-of-00003.safetensors:  72% 2.60G/3.59G [02:50<00:59, 16.5MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.73G/4.95G [02:50<02:16, 16.3MB/s]
#
#
# model-00003-of-00003.safetensors:  73% 2.61G/3.59G [02:51<01:03, 15.5MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.74G/4.95G [02:51<02:26, 15.1MB/s]
#
# model-00002-of-00003.safetensors:  56% 2.75G/4.95G [02:53<04:03, 9.04MB/s]
#
# model-00002-of-00003.safetensors:  56% 2.78G/4.95G [02:54<02:01, 17.8MB/s]
#
#
# model-00003-of-00003.safetensors:  73% 2.62G/3.59G [02:54<01:43, 9.32MB/s]
#
#
# model-00003-of-00003.safetensors:  74% 2.64G/3.59G [02:54<01:07, 14.0MB/s]
#
#
# ...
# model.layers.10.self_attn.q_proj.weight: Applied SLERP to 39.94% of parameters
# model.layers.10.self_attn.k_proj.weight: Applied SLERP to 29.93% of parameters
# model.layers.10.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.10.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.input_layernorm.weight: Applied SLERP to 33.20% of parameters
# model.layers.10.post_attention_layernorm.weight: Applied SLERP to 16.63% of parameters
# model.layers.11.self_attn.q_proj.weight: Applied SLERP to 85.69% of parameters
# model.layers.11.self_attn.k_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.11.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.11.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.11.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.11.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.11.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.11.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.11.post_attention_layernorm.weight: Applied SLERP to 33.20% of parameters
# model.layers.12.self_attn.q_proj.weight: Applied SLERP to 29.93% of parameters
# model.layers.12.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.self_attn.v_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.12.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.input_layernorm.weight: Applied SLERP to 14.16% of parameters
# model.layers.12.post_attention_layernorm.weight: Applied SLERP to 33.30% of parameters
# model.layers.13.self_attn.q_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.13.self_attn.k_proj.weight: Applied SLERP to 10.94% of parameters
# model.layers.13.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.13.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.13.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.13.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.13.mlp.down_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.13.input_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.13.post_attention_layernorm.weight: Applied SLERP to 28.47% of parameters
# model.layers.14.self_attn.q_proj.weight: Applied SLERP to 28.47% of parameters
# model.layers.14.self_attn.k_proj.weight: Applied SLERP to 42.77% of parameters
# model.layers.14.self_attn.v_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.14.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.14.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.14.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.14.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.14.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.14.post_attention_layernorm.weight: Applied SLERP to 19.92% of parameters
# model.layers.15.self_attn.q_proj.weight: Applied SLERP to 28.47% of parameters
# model.layers.15.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.self_attn.v_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.15.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.15.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.post_attention_layernorm.weight: Applied SLERP to 29.93% of parameters
# model.layers.16.self_attn.q_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.16.self_attn.k_proj.weight: Applied SLERP to 25.00% of parameters
# model.layers.16.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.16.self_attn.o_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.16.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.16.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.16.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.16.input_layernorm.weight: Applied SLERP to 55.47% of parameters
# model.layers.16.post_attention_layernorm.weight: Applied SLERP to 25.00% of parameters
# model.layers.17.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.17.self_attn.k_proj.weight: Applied SLERP to 55.47% of parameters
# model.layers.17.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.17.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.17.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.17.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.17.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.17.input_layernorm.weight: Applied SLERP to 57.08% of parameters
# model.layers.17.post_attention_layernorm.weight: Applied SLERP to 16.63% of parameters
# model.layers.18.self_attn.q_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.18.self_attn.k_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.18.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.18.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.input_layernorm.weight: Applied SLERP to 14.16% of parameters
# model.layers.18.post_attention_layernorm.weight: Applied SLERP to 33.30% of parameters
# model.layers.19.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.19.self_attn.k_proj.weight: Applied SLERP to 50.00% of parameters
# model.layers.19.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.19.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.input_layernorm.weight: Applied SLERP to 29.93% of parameters
# model.layers.19.post_attention_layernorm.weight: Applied SLERP to 57.08% of parameters
# model.layers.20.self_attn.q_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.20.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.20.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.20.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.input_layernorm.weight: Applied SLERP to 83.33% of parameters
# model.layers.20.post_attention_layernorm.weight: Applied SLERP to 59.96% of parameters
# model.layers.21.self_attn.q_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.21.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.21.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.21.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.input_layernorm.weight: Applied SLERP to 49.98% of parameters
# model.layers.21.post_attention_layernorm.weight: Applied SLERP to 25.00% of parameters
# model.layers.22.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.22.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.22.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.post_attention_layernorm.weight: Applied SLERP to 59.96% of parameters
# model.layers.23.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.self_attn.k_proj.weight: Applied SLERP to 66.65% of parameters
# model.layers.23.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.23.mlp.gate_proj.weight: Applied SLERP to 80.00% of parameters
# model.layers.23.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.23.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.23.input_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.23.post_attention_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.24.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.24.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.24.self_attn.v_proj.weight: Applied SLERP to 87.50% of parameters
# model.layers.24.self_attn.o_proj.weight: Applied SLERP to 44.34% of parameters
# model.layers.24.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.24.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.24.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.24.input_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.24.post_attention_layernorm.weight: Applied SLERP to 22.07% of parameters
# model.layers.25.self_attn.q_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.25.self_attn.k_proj.weight: Applied SLERP to 83.33% of parameters
# model.layers.25.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.25.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.25.mlp.gate_proj.weight: Applied SLERP to 44.40% of parameters
# model.layers.25.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.25.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.25.input_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.25.post_attention_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.26.self_attn.q_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.26.self_attn.k_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.26.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.26.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.26.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.26.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.26.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.26.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.26.post_attention_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.27.self_attn.q_proj.weight: Applied SLERP to 87.50% of parameters
# model.layers.27.self_attn.k_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.27.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.27.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.27.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.27.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.27.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.27.input_layernorm.weight: Applied SLERP to 71.39% of parameters
# model.layers.27.post_attention_layernorm.weight: Applied SLERP to 39.94% of parameters
# model.layers.28.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.28.self_attn.k_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.28.self_attn.v_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.28.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.28.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.28.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.28.mlp.down_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.28.input_layernorm.weight: Applied SLERP to 37.50% of parameters
# model.layers.28.post_attention_layernorm.weight: Applied SLERP to 50.00% of parameters
# model.layers.29.self_attn.q_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.29.self_attn.k_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.29.self_attn.v_proj.weight: Applied SLERP to 29.93% of parameters
# model.layers.29.self_attn.o_proj.weight: Applied SLERP to 29.93% of parameters
# model.layers.29.mlp.gate_proj.weight: Applied SLERP to 77.76% of parameters
# model.layers.29.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.29.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.29.input_layernorm.weight: Applied SLERP to 39.94% of parameters
# model.layers.29.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.30.self_attn.q_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.30.self_attn.k_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.30.self_attn.v_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.30.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.30.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.30.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.30.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.30.input_layernorm.weight: Applied SLERP to 59.96% of parameters
# model.layers.30.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.self_attn.q_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.31.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.31.self_attn.o_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.31.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.input_layernorm.weight: Applied SLERP to 29.93% of parameters
# model.layers.31.post_attention_layernorm.weight: Applied SLERP to 12.50% of parameters
# model.norm.weight: Applied SLERP to 0.00% of parameters
# lm_head.weight: Applied SLERP to 66.66% of parameters
# Replacing base model
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.31s/it]
# tokenizer_config.json: 100% 980/980 [00:00<00:00, 11.5MB/s]
# tokenizer.json: 3.62MB [00:00, 55.9MB/s]
# special_tokens_map.json: 100% 414/414 [00:00<00:00, 4.17MB/s]
# Saving merged model to ./slerp_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7

# %%
# !slerp_merge \
yedi-hu/slerp_llama_2_child-2-6-float16 \
yedi-hu/Llama-2-7b-truthfulqa-float16 \
./slerp_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7\
-m change_gsm8k_mask
# Out:
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.21s/it]
# Loading checkpoint shards: 100% 3/3 [00:34<00:00, 11.35s/it]
# model.embed_tokens.weight: Applied SLERP to 100.00% of parameters
# model.layers.0.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.0.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.0.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.0.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.0.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.0.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.0.mlp.down_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.0.input_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.0.post_attention_layernorm.weight: Applied SLERP to 77.73% of parameters
# model.layers.1.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.1.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.1.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.1.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.1.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.1.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.1.mlp.down_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.1.input_layernorm.weight: Applied SLERP to 49.95% of parameters
# model.layers.1.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.2.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.2.self_attn.k_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.2.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.2.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.2.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.2.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.2.mlp.down_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.2.input_layernorm.weight: Applied SLERP to 77.73% of parameters
# model.layers.2.post_attention_layernorm.weight: Applied SLERP to 88.87% of parameters
# model.layers.3.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.3.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.3.self_attn.v_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.3.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.3.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.3.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.3.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.3.input_layernorm.weight: Applied SLERP to 88.87% of parameters
# model.layers.3.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.4.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.4.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.4.self_attn.v_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.4.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.4.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.4.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.4.mlp.down_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.4.input_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.4.post_attention_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.5.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.5.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.5.self_attn.v_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.5.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.5.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.5.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.5.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.5.input_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.5.post_attention_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.6.self_attn.q_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.6.self_attn.k_proj.weight: Applied SLERP to 39.94% of parameters
# model.layers.6.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.6.self_attn.o_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.6.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.6.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.6.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.6.input_layernorm.weight: Applied SLERP to 88.87% of parameters
# model.layers.6.post_attention_layernorm.weight: Applied SLERP to 49.95% of parameters
# model.layers.7.self_attn.q_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.7.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.7.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.7.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.7.mlp.gate_proj.weight: Applied SLERP to 80.00% of parameters
# model.layers.7.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.7.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.7.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.7.post_attention_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.8.self_attn.q_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.8.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.8.self_attn.v_proj.weight: Applied SLERP to 29.93% of parameters
# model.layers.8.self_attn.o_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.8.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.8.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.8.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.8.input_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.8.post_attention_layernorm.weight: Applied SLERP to 88.87% of parameters
# model.layers.9.self_attn.q_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.9.self_attn.k_proj.weight: Applied SLERP to 19.92% of parameters
# model.layers.9.self_attn.v_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.9.self_attn.o_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.9.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.9.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.9.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.9.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.9.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.self_attn.q_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.10.self_attn.k_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.self_attn.v_proj.weight: Applied SLERP to 39.94% of parameters
# model.layers.10.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.10.input_layernorm.weight: Applied SLERP to 37.50% of parameters
# model.layers.10.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.11.self_attn.q_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.11.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.11.self_attn.v_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.11.self_attn.o_proj.weight: Applied SLERP to 62.50% of parameters
# model.layers.11.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.11.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.11.mlp.down_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.11.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.11.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.12.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.12.self_attn.k_proj.weight: Applied SLERP to 19.92% of parameters
# model.layers.12.self_attn.v_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.12.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.mlp.gate_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.12.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.12.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.12.post_attention_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.13.self_attn.q_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.13.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.13.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.13.self_attn.o_proj.weight: Applied SLERP to 39.94% of parameters
# model.layers.13.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.13.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.13.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.13.input_layernorm.weight: Applied SLERP to 49.95% of parameters
# model.layers.13.post_attention_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.14.self_attn.q_proj.weight: Applied SLERP to 57.08% of parameters
# model.layers.14.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.14.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.14.self_attn.o_proj.weight: Applied SLERP to 49.95% of parameters
# model.layers.14.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.14.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.14.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.14.input_layernorm.weight: Applied SLERP to 77.73% of parameters
# model.layers.14.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.15.self_attn.q_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.15.self_attn.k_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.15.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.15.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.15.mlp.gate_proj.weight: Applied SLERP to 33.28% of parameters
# model.layers.15.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.15.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.15.input_layernorm.weight: Applied SLERP to 83.33% of parameters
# model.layers.15.post_attention_layernorm.weight: Applied SLERP to 42.77% of parameters
# model.layers.16.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.16.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.16.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.16.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.16.mlp.gate_proj.weight: Applied SLERP to 90.00% of parameters
# model.layers.16.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.16.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.16.input_layernorm.weight: Applied SLERP to 42.77% of parameters
# model.layers.16.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.17.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.17.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.17.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.17.self_attn.o_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.17.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.17.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.17.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.17.input_layernorm.weight: Applied SLERP to 50.00% of parameters
# model.layers.17.post_attention_layernorm.weight: Applied SLERP to 71.39% of parameters
# model.layers.18.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.18.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.18.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.18.self_attn.o_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.18.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.18.input_layernorm.weight: Applied SLERP to 66.65% of parameters
# model.layers.18.post_attention_layernorm.weight: Applied SLERP to 59.96% of parameters
# model.layers.19.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.19.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.19.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.19.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.19.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.19.input_layernorm.weight: Applied SLERP to 69.97% of parameters
# model.layers.19.post_attention_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.20.self_attn.q_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.20.self_attn.k_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.20.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.20.self_attn.o_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.20.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.20.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.20.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.20.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.self_attn.q_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.21.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.21.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.21.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.21.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.21.input_layernorm.weight: Applied SLERP to 9.91% of parameters
# model.layers.21.post_attention_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.22.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.22.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.22.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.mlp.down_proj.weight: Applied SLERP to 28.47% of parameters
# model.layers.22.input_layernorm.weight: Applied SLERP to 0.00% of parameters
# model.layers.22.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.self_attn.q_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.23.self_attn.k_proj.weight: Applied SLERP to 85.69% of parameters
# model.layers.23.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.self_attn.o_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.23.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.23.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.23.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.23.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.24.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.24.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.24.self_attn.v_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.24.self_attn.o_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.24.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.24.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.24.mlp.down_proj.weight: Applied SLERP to 75.00% of parameters
# model.layers.24.input_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.24.post_attention_layernorm.weight: Applied SLERP to 77.73% of parameters
# model.layers.25.self_attn.q_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.25.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.25.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.25.self_attn.o_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.25.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.25.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.25.mlp.down_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.25.input_layernorm.weight: Applied SLERP to 89.99% of parameters
# model.layers.25.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.26.self_attn.q_proj.weight: Applied SLERP to 83.33% of parameters
# model.layers.26.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.26.self_attn.v_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.26.self_attn.o_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.26.mlp.gate_proj.weight: Applied SLERP to 77.76% of parameters
# model.layers.26.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.26.mlp.down_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.26.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.26.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.27.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.27.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.27.self_attn.v_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.27.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.27.mlp.gate_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.27.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.27.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.27.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.27.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.28.self_attn.q_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.28.self_attn.k_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.28.self_attn.v_proj.weight: Applied SLERP to 87.50% of parameters
# model.layers.28.self_attn.o_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.28.mlp.gate_proj.weight: Applied SLERP to 90.00% of parameters
# model.layers.28.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.28.mlp.down_proj.weight: Applied SLERP to 39.94% of parameters
# model.layers.28.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.28.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.29.self_attn.q_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.29.self_attn.k_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.29.self_attn.v_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.29.self_attn.o_proj.weight: Applied SLERP to 88.87% of parameters
# model.layers.29.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.29.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.29.mlp.down_proj.weight: Applied SLERP to 69.97% of parameters
# model.layers.29.input_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.29.post_attention_layernorm.weight: Applied SLERP to 100.00% of parameters
# model.layers.30.self_attn.q_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.30.self_attn.k_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.30.self_attn.v_proj.weight: Applied SLERP to 77.73% of parameters
# model.layers.30.self_attn.o_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.30.mlp.gate_proj.weight: Applied SLERP to 14.26% of parameters
# model.layers.30.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.30.mlp.down_proj.weight: Applied SLERP to 89.99% of parameters
# model.layers.30.input_layernorm.weight: Applied SLERP to 88.87% of parameters
# model.layers.30.post_attention_layernorm.weight: Applied SLERP to 39.94% of parameters
# model.layers.31.self_attn.q_proj.weight: Applied SLERP to 100.00% of parameters
# model.layers.31.self_attn.k_proj.weight: Applied SLERP to 66.60% of parameters
# model.layers.31.self_attn.v_proj.weight: Applied SLERP to 79.98% of parameters
# model.layers.31.self_attn.o_proj.weight: Applied SLERP to 59.96% of parameters
# model.layers.31.mlp.gate_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.mlp.up_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.mlp.down_proj.weight: Applied SLERP to 0.00% of parameters
# model.layers.31.input_layernorm.weight: Applied SLERP to 79.98% of parameters
# model.layers.31.post_attention_layernorm.weight: Applied SLERP to 14.16% of parameters
# model.norm.weight: Applied SLERP to 79.98% of parameters
# lm_head.weight: Applied SLERP to 90.00% of parameters
# Replacing base model
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.18s/it]
# Saving merged model to ./slerp_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7

# %%
from huggingface_hub import HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'slerp_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7' # @param {"type":"string"}
repo_name=f'yedi-hu/{model_name}'
model_path=f'./{model_name}'
token='yours'

api = HfApi()

try:
    api.create_repo(
        repo_id=repo_name,
        private=False,
        exist_ok=True
      )
except Exception as e:
      raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")

  # Load the model and tokenizer
# model = AutoModelForCausalLM.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

api.upload_folder(
    folder_path=model_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)


print(f"✅ Model successfully uploaded to: https://huggingface.co/{repo_name}")
# Out:
# Uploading model to yedi-hu/slerp_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# ✅ Model successfully uploaded to: https://huggingface.co/yedi-hu/slerp_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7

# %%
from huggingface_hub import HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'slerp_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7' # @param {"type":"string"}
repo_name=f'yedi-hu/{model_name}'
model_path=f'./{model_name}'
token='yours'

api = HfApi()

try:
    api.create_repo(
        repo_id=repo_name,
        private=False,
        exist_ok=True
      )
except Exception as e:
      raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")

  # Load the model and tokenizer
# model = AutoModelForCausalLM.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

api.upload_folder(
    folder_path=model_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)


print(f"✅ Model successfully uploaded to: https://huggingface.co/{repo_name}")
# Out:
# Uploading model to yedi-hu/slerp_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7...
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# ✅ Model successfully uploaded to: https://huggingface.co/yedi-hu/slerp_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7

# %% [markdown]
# ## Replace

# %%
Replace_name = 'replace_llama_2_child-3-2-float16-elastic-truthfulqa-mask-0.7' # @param {"type":"string"}
cli = f'replace_merge \
yedi-hu/slerp_llama_2_child-2-6-float16 \
yedi-hu/Llama-2-7b-truthfulqa-float16 \
change_truthfulqa_mask \
{Replace_name}'
# !{cli}
# Out:
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.19s/it]
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.16s/it]
# Loading checkpoint shards: 100% 3/3 [00:33<00:00, 11.18s/it]
# Successfully replaced masked areas, saved to: replace_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7

# %% [markdown]
# ## Update

# %%
from huggingface_hub import HfApi
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = 'replace_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7' # @param {"type":"string"}
repo_name=f'yedi-hu/{model_name}'
model_path=f'./{model_name}'
token='yours'

api = HfApi()

try:
    api.create_repo(
        repo_id=repo_name,
        private=False,
        exist_ok=True
      )
except Exception as e:
      raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")

  # Load the model and tokenizer
# model = AutoModelForCausalLM.from_pretrained(model_path)
# tokenizer = AutoTokenizer.from_pretrained(model_path)

api.upload_folder(
    folder_path=model_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)


print(f"✅ Model successfully uploaded to: https://huggingface.co/{repo_name}")
# Out:
# Uploading model to yedi-hu/replace_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7...
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/3.59G [00:00<?, ?B/s]
# ✅ Model successfully uploaded to: https://huggingface.co/yedi-hu/replace_llama_2_child-3-2-float16-elastic-gsm8k-mask-0.7

# %%
user = 'yedi-hu/'
repo_name = user+'task_masks'
output_path = './task_masks/'
try:
  api.create_repo(
      repo_id=repo_name,
      private=False,
      exist_ok=True
    )
except Exception as e:
    raise Exception(f"Failed to create repository: {str(e)}")

print(f"Uploading model to {repo_name}...")


api.upload_folder(
    folder_path=output_path,
    repo_id=repo_name,
    repo_type="model",
    commit_message="Upload model files",
)
